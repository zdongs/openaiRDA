# %% [markdown]
# 本notebook：
# - 修改prompt，让llm将职责拆成两部分
# - 根据岗位名称筛选特定大领域岗位信息
# - 取llm返回的每个岗位信息的embedding，求余弦相似度，使相似性过强的岗位信息共用一个提取结果

# %%
import pandas as pd

data = pd.read_csv("D:\AI\AI-job-analysis\data_merge\merged_data_final.csv")
cv_condition = data["岗位名称"].str.contains("CV|视觉|图像|图形")

# %%
cv_data = data[cv_condition]
# 小批量测试数据
mini_cv_data = cv_data[2:6]
len(cv_data)
# Out:
# 499

# %%
mini_cv_data.iloc[0]["岗位要求"]
# Out:
# '关于感知方向\n感知是无人驾驶中非常复杂和有趣的部分之一，你构建的是一个人工智能集大成的系统，不是一项按部就班就能完成的工作！感知软件工程师负责无人驾驶感知系统的设计和实现，应对无人驾驶中各种最有挑战的问题：\n1. 设计高效可靠的深度学习模型，在几十毫秒内精确检测和跟踪车周围200米之内所有的障碍物（人，车，非机动车辆，交通锥等），并对场景进行理解\n2. 如何设计一般性的模型和算法去处理各式各样的长尾情况和极端环境，如路面上的垃圾袋，洒水车的水花，前车掉下来的挡板 ，如大雨，大雪，雾霾，风沙等\n3. 如何保证感知模型和算法在极端的环境里的准确性和可靠性，如大雨，大雪，雾霾，风沙等\n4. 把模型优化到极致，让十几个到几十个模型在车上有限的计算资源上欢快的运行\n5. 如何搭建一个高效可靠的计算框架，支撑一个周期内接收几十个传感器的输入，做各种同步融合，并进行几十个深度学习模型的推理\n关于机器学习和算法方向\n这个方向的感知工程师负责设计并实现传感器标定，障碍物检测，分类，跟踪，和场景理解等各种模型和算法，对模型和算法进行评估和测试，并把模型和算法部署到车上。\n我们需要你：\n- 同时具有很强的算法和C++编程能力；或者在机器学习/深度学习，计算机视觉，模型优化等至少一个方向上有扎实的基础和丰富的经验。\n- 拥有强大的逻辑思维能力，算法能力，以及解决问题的能力。\n- 具有良好的沟通能力和跨组合作能力。\n- 具有强烈的自我驱动能力对无人驾驶真正的 believe 。\n加分项：\n- 丰富的C++开发经验，熟悉多线程，内存管理，泛型，及设计模式.\n- 丰富多传感器融合以及2d/3d跟踪的经验\n- 在顶会发表了文章'

# %%
import pickle

# 读取缓存文件，若缓存文件不存在或者为空（初次运行），则初始化一个空的字典
try:
    with open("data/all_keyword_dic.cache", "rb") as f:
        new_cache = pickle.load(f)
except:
    print("Empty cache file")
    new_cache = {}

try:
    with open("data/s2e.cache", "rb") as f:
        s2e = pickle.load(f)
except:
    print("Empty s2e file")
    s2e = {}

# %%
from test import *
# from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import json


for text in cv_data["岗位要求"]:
    prompt = f"""
请提取招聘信息中岗位所涉及的与招聘相关的关键词，分别为“语言需求”、“框架需求”、“业务领域”、“算法与开发”和“其他要求”。

关键词个数限制：
- 业务领域关键词不超过3个，更侧重表示金融、无人驾驶等与具体算法、技术无关的领域，不包括如“图像处理”等与算法、技术等相关领域。
- 框架需求关键词必须表示框架、库的要求，例如TensorFlow、PyTorch等。
- 算法与开发关键词侧重表示算法、模型、技术、工程、具体工作内容的要求，例如图像分类、目标检测、GAN、算法研究等。
- 其他要求中包括素质要求、学历要求、工作经验要求、优先条件等。
- 关键词应该具有一定的复杂性，避免过于简单的词汇，例如“算法研究”而不是“研究”或“算法”。
- 关键词中避免出现由或、和、顿号等连接的并列词汇，例如“有相关顶会论文或竞赛经验的优先”应当拆分为“顶会论文”“竞赛经验”
- 关键词中避免出现口语化表达和程度表达，例如“熟悉”“了解”“较好的”“良好的”等
- 若某一关键词类别不存在，则该关键词必须返回空列表，不要填入不完全属于该类别的内容

返回格式：
返回json，key为给定的6种关键词类别，value为具有一定复杂性的词汇的列表。
```
{text}
```
"""
    if text not in s2e:
        # get_embedding后，将文本与之前的文本进行相似度比较，如果相似度大于0.9，则将之前的文本的处理结果复制给当前文本
        s2e[text] = get_embedding(text, model="text-embedding-ada-002")
    for k, v in s2e.items():
        if k != text:
            if cosine_similarity(np.array(v), np.array(s2e[text])) > 0.988:
                print(k, "\n=========\n", text)
                new_cache[text] = new_cache[k]
                break
    # 如果文本已在缓存区，则跳过
    if text in new_cache:
        continue
    # 否则，进行ChatGPT_request
    jsons = ChatGPT_request(prompt)
    print(text)
    print("====================================")
    print(jsons)
    # 将ChatGPT_request的结果存入缓存区
    new_cache[text] = json.loads(jsons)
# Out:
# 职位描述：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# =========
#  岗位职责：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# 职位描述：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# =========
#  岗位要求
# 职位描述：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# 岗位要求
# 职位描述：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# =========
#  职位描述：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# 职位描述
# 部署加速
# 岗位职责及主要工作描述
# 负责视觉类算法的部署优化，将相关算法进行工程化落地实现。
# 负责视觉相关的算法在嵌入式设备（NPU、GPU等AI芯片）上的轻量化与部署；
# 负责业务的视觉感知算法的研发和迭代；
# 负责真实业务场景的问题分析、跟踪及解决。
# 专业技能要求
# 熟练使用C/C++、CUDA、Python，有良好的数据结构和算法基础，熟悉Linux开发环境；
# 掌握AI算法加速、量化、剪枝，模型搜索相关的技术及工具链；
# 具有深度学习算法模型量化移植和应用落地经验，具备独立进行算法应用问题排查及定位能力；
# 有Jetson GPU、Atlas等相关芯片移植优化经验者优先；
# 良好的团队合作，沟通和协作能力
# 可解决北京工作居住证，表现优异者协助解决户口，以及发放期权激励。
# 应届生可解决北京户口
# =========
#  职位描述
# 视觉图像算法部署加速
# 岗位职责及主要工作描述
# 负责视觉类算法的部署优化，将相关算法进行工程化落地实现。
# 负责视觉相关的算法在嵌入式设备（NPU、GPU等AI芯片）上的轻量化与部署；
# 负责业务的视觉感知算法的研发和迭代；
# 负责真实业务场景的问题分析、跟踪及解决。
# 专业技能要求
# 熟练使用C/C++、CUDA、Python，有良好的数据结构和算法基础，熟悉Linux开发环境；
# 掌握AI算法加速、量化、剪枝，模型搜索相关的技术及工具链；
# 具有深度学习算法模型量化移植和应用落地经验，具备独立进行算法应用问题排查及定位能力；
# 有Jetson GPU、Atlas等相关芯片移植优化经验者优先；
# 良好的团队合作，沟通和协作能力
# 可解决北京工作居住证，表现优异者协助解决户口，以及发放期权激励。
# 应届生可解决北京户口
# 职位描述
# 视觉图像算法部署加速
# 岗位职责及主要工作描述
# 负责视觉类算法的部署优化，将相关算法进行工程化落地实现。
# 负责视觉相关的算法在嵌入式设备（NPU、GPU等AI芯片）上的轻量化与部署；
# 负责业务的视觉感知算法的研发和迭代；
# 负责真实业务场景的问题分析、跟踪及解决。
# 专业技能要求
# 熟练使用C/C++、CUDA、Python，有良好的数据结构和算法基础，熟悉Linux开发环境；
# 掌握AI算法加速、量化、剪枝，模型搜索相关的技术及工具链；
# 具有深度学习算法模型量化移植和应用落地经验，具备独立进行算法应用问题排查及定位能力；
# 有Jetson GPU、Atlas等相关芯片移植优化经验者优先；
# 良好的团队合作，沟通和协作能力
# 可解决北京工作居住证，表现优异者协助解决户口，以及发放期权激励。
# 应届生可解决北京户口
# =========
#  职位描述
# 部署加速
# 岗位职责及主要工作描述
# 负责视觉类算法的部署优化，将相关算法进行工程化落地实现。
# 负责视觉相关的算法在嵌入式设备（NPU、GPU等AI芯片）上的轻量化与部署；
# 负责业务的视觉感知算法的研发和迭代；
# 负责真实业务场景的问题分析、跟踪及解决。
# 专业技能要求
# 熟练使用C/C++、CUDA、Python，有良好的数据结构和算法基础，熟悉Linux开发环境；
# 掌握AI算法加速、量化、剪枝，模型搜索相关的技术及工具链；
# 具有深度学习算法模型量化移植和应用落地经验，具备独立进行算法应用问题排查及定位能力；
# 有Jetson GPU、Atlas等相关芯片移植优化经验者优先；
# 良好的团队合作，沟通和协作能力
# 可解决北京工作居住证，表现优异者协助解决户口，以及发放期权激励。
# 应届生可解决北京户口
# 职位描述
# 视觉图像算法部署加速
# 岗位职责及主要工作描述
# 负责视觉类算法的部署优化，将相关算法进行工程化落地实现。
# 负责视觉相关的算法在嵌入式设备（NPU、GPU等AI芯片）上的轻量化与部署；
# 负责业务的视觉感知算法的研发和迭代；
# 负责真实业务场景的问题分析、跟踪及解决。
# 专业技能要求
# 熟练使用C/C++、CUDA、Python，有良好的数据结构和算法基础，熟悉Linux开发环境；
# 掌握AI算法加速、量化、剪枝，模型搜索相关的技术及工具链；
# 具有深度学习算法模型量化移植和应用落地经验，具备独立进行算法应用问题排查及定位能力；
# 有Jetson GPU、Atlas等相关芯片移植优化经验者优先；
# 良好的团队合作，沟通和协作能力
# 可解决北京工作居住证，表现优异者协助解决户口，以及发放期权激励。
# 应届生可解决北京户口
# =========
#  职位描述
# 部署加速
# 岗位职责及主要工作描述
# 负责视觉类算法的部署优化，将相关算法进行工程化落地实现。
# 负责视觉相关的算法在嵌入式设备（NPU、GPU等AI芯片）上的轻量化与部署；
# 负责业务的视觉感知算法的研发和迭代；
# 负责真实业务场景的问题分析、跟踪及解决。
# 专业技能要求
# 熟练使用C/C++、CUDA、Python，有良好的数据结构和算法基础，熟悉Linux开发环境；
# 掌握AI算法加速、量化、剪枝，模型搜索相关的技术及工具链；
# 具有深度学习算法模型量化移植和应用落地经验，具备独立进行算法应用问题排查及定位能力；
# 有Jetson GPU、Atlas等相关芯片移植优化经验者优先；
# 良好的团队合作，沟通和协作能力
# 可解决北京工作居住证，表现优异者协助解决户口，以及发放期权激励。
# 应届生可解决北京户口
# 职位描述
# 基础语言模型CV/AIGC
# 工作地址：
# 1.浙江省杭州市余杭区文一西路969号阿里巴巴西溪园区
# 2.北京北京北京市朝阳区望京东园四区（望京阿里中心）
# 薪酬open，初中高级都在招聘~25w-80w,年终奖，住房补等。
# 岗位1：
# 1、研究生成式预训练语言模型技术；
# 2、研究对齐技术，如SFT、RLHF等；
# 3、结合业务研究应用技术，如LangChain、检索增强、API调用等。
# 岗位要求：
# 1.自然语言处理、机器学习、数据挖掘、人工智能等相关专业的硕士生/博士生；2.熟练掌握tensorflow、pytorch等深度学习框架，扎实的编程基础；
# 3.在人工智能相关的各类国际顶级会议/期刊中发表过论文者优先；
# 4.有丰富的相关领域经验，或者ACM等顶级竞赛获奖者优先。
# 岗位2：
# 1、利用AIGC相关算法（StableDiffusion/ControlNet等），实现创新的技术方案和业务方案，在C端场景落地应用，如上身搭配/商品编辑等；
# 2、基于淘宝丰富的商品信息数据，利用多模态信息抽取、视觉语言模型等算法，建设拍立淘百科能力；
# 3、负责拍立淘端侧算法，利用端上分类、检测、跟踪等视频流技术，为图搜的质量、体验带来新的增量。
# 岗位要求：
# 1、计算机、人工智能、数学等相关专业，本科/硕士/博士；
# 2、具备扎实的计算机视觉/机器学习/深度学习理论功底和算法经验，有相关方向的顶级论文者优先；
# 3、有解决过较复杂的业务问题并带来业务提升者优先；
# 4、有很强的创新能力，能够解决高挑战性问题，自我驱动能力强，并且有独立完成任务的能力；同时，具有良好的沟通技能和抗压能力。
# 更多算法职位单独详细沟通~
# =========
#  职位描述
# 基础语言模型CV/AIGC
# 薪酬open，初中高级都在招聘~25w-80w,年终奖，住房补等。
# 工作地址：
# 1.浙江省杭州市余杭区文一西路969号阿里巴巴西溪园区
# 2.北京北京北京市朝阳区望京东园四区（望京阿里中心）
# 岗位1：
# 1、研究生成式预训练语言模型技术；
# 2、研究对齐技术，如SFT、RLHF等；
# 3、结合业务研究应用技术，如LangChain、检索增强、API调用等。
# 岗位要求：
# 1.自然语言处理、机器学习、数据挖掘、人工智能等相关专业的硕士生/博士生；2.熟练掌握tensorflow、pytorch等深度学习框架，扎实的编程基础；
# 3.在人工智能相关的各类国际顶级会议/期刊中发表过论文者优先；
# 4.有丰富的相关领域经验，或者ACM等顶级竞赛获奖者优先。
# 岗位2：
# 1、利用AIGC相关算法（StableDiffusion/ControlNet等），实现创新的技术方案和业务方案，在C端场景落地应用，如上身搭配/商品编辑等；
# 2、基于淘宝丰富的商品信息数据，利用多模态信息抽取、视觉语言模型等算法，建设拍立淘百科能力；
# 3、负责拍立淘端侧算法，利用端上分类、检测、跟踪等视频流技术，为图搜的质量、体验带来新的增量。
# 岗位要求：
# 1、计算机、人工智能、数学等相关专业，本科/硕士/博士；
# 2、具备扎实的计算机视觉/机器学习/深度学习理论功底和算法经验，有相关方向的顶级论文者优先；
# 3、有解决过较复杂的业务问题并带来业务提升者优先；
# 4、有很强的创新能力，能够解决高挑战性问题，自我驱动能力强，并且有独立完成任务的能力；同时，具有良好的沟通技能和抗压能力。
# 职位描述
# 基础语言模型CV/AIGC
# 薪酬open，初中高级都在招聘~25w-80w,年终奖，住房补等。
# 工作地址：
# 1.浙江省杭州市余杭区文一西路969号阿里巴巴西溪园区
# 2.北京北京北京市朝阳区望京东园四区（望京阿里中心）
# 岗位1：
# 1、研究生成式预训练语言模型技术；
# 2、研究对齐技术，如SFT、RLHF等；
# 3、结合业务研究应用技术，如LangChain、检索增强、API调用等。
# 岗位要求：
# 1.自然语言处理、机器学习、数据挖掘、人工智能等相关专业的硕士生/博士生；2.熟练掌握tensorflow、pytorch等深度学习框架，扎实的编程基础；
# 3.在人工智能相关的各类国际顶级会议/期刊中发表过论文者优先；
# 4.有丰富的相关领域经验，或者ACM等顶级竞赛获奖者优先。
# 岗位2：
# 1、利用AIGC相关算法（StableDiffusion/ControlNet等），实现创新的技术方案和业务方案，在C端场景落地应用，如上身搭配/商品编辑等；
# 2、基于淘宝丰富的商品信息数据，利用多模态信息抽取、视觉语言模型等算法，建设拍立淘百科能力；
# 3、负责拍立淘端侧算法，利用端上分类、检测、跟踪等视频流技术，为图搜的质量、体验带来新的增量。
# 岗位要求：
# 1、计算机、人工智能、数学等相关专业，本科/硕士/博士；
# 2、具备扎实的计算机视觉/机器学习/深度学习理论功底和算法经验，有相关方向的顶级论文者优先；
# 3、有解决过较复杂的业务问题并带来业务提升者优先；
# 4、有很强的创新能力，能够解决高挑战性问题，自我驱动能力强，并且有独立完成任务的能力；同时，具有良好的沟通技能和抗压能力。
# =========
#  职位描述
# 基础语言模型CV/AIGC
# 工作地址：
# 1.浙江省杭州市余杭区文一西路969号阿里巴巴西溪园区
# 2.北京北京北京市朝阳区望京东园四区（望京阿里中心）
# 薪酬open，初中高级都在招聘~25w-80w,年终奖，住房补等。
# 岗位1：
# 1、研究生成式预训练语言模型技术；
# 2、研究对齐技术，如SFT、RLHF等；
# 3、结合业务研究应用技术，如LangChain、检索增强、API调用等。
# 岗位要求：
# 1.自然语言处理、机器学习、数据挖掘、人工智能等相关专业的硕士生/博士生；2.熟练掌握tensorflow、pytorch等深度学习框架，扎实的编程基础；
# 3.在人工智能相关的各类国际顶级会议/期刊中发表过论文者优先；
# 4.有丰富的相关领域经验，或者ACM等顶级竞赛获奖者优先。
# 岗位2：
# 1、利用AIGC相关算法（StableDiffusion/ControlNet等），实现创新的技术方案和业务方案，在C端场景落地应用，如上身搭配/商品编辑等；
# 2、基于淘宝丰富的商品信息数据，利用多模态信息抽取、视觉语言模型等算法，建设拍立淘百科能力；
# 3、负责拍立淘端侧算法，利用端上分类、检测、跟踪等视频流技术，为图搜的质量、体验带来新的增量。
# 岗位要求：
# 1、计算机、人工智能、数学等相关专业，本科/硕士/博士；
# 2、具备扎实的计算机视觉/机器学习/深度学习理论功底和算法经验，有相关方向的顶级论文者优先；
# 3、有解决过较复杂的业务问题并带来业务提升者优先；
# 4、有很强的创新能力，能够解决高挑战性问题，自我驱动能力强，并且有独立完成任务的能力；同时，具有良好的沟通技能和抗压能力。
# 更多算法职位单独详细沟通~
# 1. 负责数字人相关算法前沿技术研发，包括但不限于数字人动画生成及驱动（动作、表情、口型），实现千人千面的数字人建模与驱动
# 2. 负责数字人算法的实现和优化，保证算法的高效性和稳定性
# 3. 参与数字人产品的技术方案设计，并且和上下游紧密配合，推动技术落地
# 职位描述
# 1. 扎实的计算机视觉基础，独立分析和解决问题的能力，良好的沟通能力
# 2. 熟悉数字人领域的人脸/人体3D重建、表情/动作驱动、口型生成以及GAN/Diffusion Model等生成式算法
# 3. 较强的工程实现能力，精通PyTorch/Tensorflow等深度学习架构之一
# 4. 较好的相关相关文献阅读及理解能力，在SIGGRAPH/CVPR/ICCV/ECCV/NeurIPS/TPAMI等发表论文者优先，具有2D、2.5D、3D数字人算法开发经验，具备量产经验者优先
# 5. 对于新产品/新技术有着浓厚的兴趣，热爱创新
# =========
#  职位描述
# 1. 负责数字人相关算法前沿技术研发，包括但不限于数字人动画生成及驱动（动作、表情、口型），实现千人千面的数字人建模与驱动
# 2. 负责数字人算法的实现和优化，保证算法的高效性和稳定性
# 3. 参与数字人产品的技术方案设计，并且和上下游紧密配合，推动技术落地
# 职位要求
# 1. 扎实的计算机视觉基础，独立分析和解决问题的能力，良好的沟通能力
# 2. 熟悉数字人领域的人脸/人体3D重建、表情/动作驱动、口型生成以及GAN/Diffusion Model等生成式算法
# 3. 较强的工程实现能力，精通PyTorch/Tensorflow等深度学习架构之一
# 4. 较好的相关相关文献阅读及理解能力，在SIGGRAPH/CVPR/ICCV/ECCV/NeurIPS/TPAMI等发表论文者优先，具有2D、2.5D、3D数字人算法开发经验，具备量产经验者优先
# 5. 对于新产品/新技术有着浓厚的兴趣，热爱创新
# 职位描述
# 1. 负责数字人相关算法前沿技术研发，包括但不限于数字人动画生成及驱动（动作、表情、口型），实现千人千面的数字人建模与驱动
# 2. 负责数字人算法的实现和优化，保证算法的高效性和稳定性
# 3. 参与数字人产品的技术方案设计，并且和上下游紧密配合，推动技术落地
# 职位要求
# 1. 扎实的计算机视觉基础，独立分析和解决问题的能力，良好的沟通能力
# 2. 熟悉数字人领域的人脸/人体3D重建、表情/动作驱动、口型生成以及GAN/Diffusion Model等生成式算法
# 3. 较强的工程实现能力，精通PyTorch/Tensorflow等深度学习架构之一
# 4. 较好的相关相关文献阅读及理解能力，在SIGGRAPH/CVPR/ICCV/ECCV/NeurIPS/TPAMI等发表论文者优先，具有2D、2.5D、3D数字人算法开发经验，具备量产经验者优先
# 5. 对于新产品/新技术有着浓厚的兴趣，热爱创新
# =========
#  岗位描述：
# 1. 负责数字人相关算法前沿技术研发，包括但不限于数字人动画生成及驱动（动作、表情、口型），实现千人千面的数字人建模与驱动
# 2. 负责数字人算法的实现和优化，保证算法的高效性和稳定性
# 3. 参与数字人产品的技术方案设计，并且和上下游紧密配合，推动技术落地
# 岗位要求：
# 1. 扎实的计算机视觉基础，独立分析和解决问题的能力，良好的沟通能力
# 2. 熟悉数字人领域的人脸/人体3D重建、表情/动作驱动、口型生成以及GAN/Diffusion Model等生成式算法
# 3. 较强的工程实现能力，精通PyTorch/Tensorflow等深度学习架构之一
# 4. 较好的相关相关文献阅读及理解能力，在SIGGRAPH/CVPR/ICCV/ECCV/NeurIPS/TPAMI等发表论文者优先，具有2D、2.5D、3D数字人算法开发经验，具备量产经验者优先
# 5. 对于新产品/新技术有着浓厚的兴趣，热爱创新
# 职责描述：
# -负责3D数字人、2D数字人相关算法的研发，打造全球领先的智能交互数字人
# -研究开发3D人脸重建、表情跟踪、表情迁移等相关算法
# -研究3D人体重建、姿态动作跟踪、运动重定向等相关算法
# -研究数字人驱动算法，从声音、音乐、文本等输入预测人脸表情、口型、情绪、手势、姿态动作
# -优化3D人脸面部绑定、人体骨骼绑定效果，开发基于blendshape和骨骼绑定的智能绑定迁移算法；
# -研究利用语音驱动真人单图或视频的talking head相关算法
# -调研数字人相关前沿技术方向
# -研发有创新性和实用价值的技术
# 任职要求：
# -计算机图形学、计算机视觉相关专业硕士及以上学历
# -对数据结构和算法设计有较为深刻的理解、具有较好的机器学习基础
# -具有优秀的分析问题和解决问题的能力，对解决具有挑战性问题充满激情
# -熟悉linux的开发环境，熟练使用C++ 、python语言（至少掌握一种）
# -熟练使用OpenCV、Eigen等，熟练使用至少一种图形学相关算法库（libigl、CGAL等）
# -熟悉PaddelPaddle/TensorFlow/Pytorch等深度学习框架（至少掌握一种）
# -有人脸合成/融合/换脸、talking head、人脸重建、人体重建相关论文/创新性工作成果优先
# -熟悉几何处理算法（拉普拉斯形变、ARAP）有加分
# -掌握模型蒸馏/量化/TensorRT/cuda加速有加分
# -熟悉动画驱动（人脸blendshape绑定、人体骨架绑定）有加分
# -熟悉一种三维建模软件（Maya）或游戏渲染引擎（unity3d，unreal engine 4等）有加分；
# ====================================
# {
#   "语言需求": ["C++", "Python"],
#   "框架需求": ["OpenCV", "Eigen", "TensorFlow", "PyTorch"],
#   "业务领域": [],
#   "算法与开发": ["3D数字人", "2D数字人", "人脸重建", "表情跟踪", "表情迁移", "人体重建", "姿态动作跟踪", "运动重定向", "数字人驱动算法", "声音预测", "音乐预测", "文本预测", "智能绑定迁移算法", "语音驱动真人", "talking head", "前沿技术", "创新性技术", "模型蒸馏", "模型量化", "TensorRT", "cuda加速", "动画驱动", "人脸blendshape绑定", "人体骨架绑定", "三维建模软件", "Maya", "游戏渲染引擎", "unity3d", "unreal engine 4"],
#   "其他要求": ["计算机图形学", "计算机视觉", "机器学习", "linux", "图形学相关算法库", "PaddelPaddle", "深度学习框架", "人脸合成", "人脸融合", "人脸换脸", "论文", "创新性工作成果", "几何处理算法"]
# }
# 岗位职责：
# 1.负责CV类深度学习模型算法研发工作，如目标检测、文本识别、图像分割、版面分析等。
# 2.负责图像算法研发与维护工作，如图像的降噪、倾斜矫正、颜色矫正、抠图等。
# 3.负责电子文档、电子公文扫描图场景下CV类深度学习模型算法和图像算法技术的研发和技术落地工作，以行业领先为目标，分析问题，制定解决方案。
# 任职要求：
# 1.本科及以上学历，计算机、数学、统计学、通信、电子工程、人工智能等相关专业。
# 2.3年以上CV模型优化相关工作经验，熟练掌握python，熟练使用常见的深度学习训练框架如pytorch、tensorflow等，熟悉模型调优过程中各种问题的解决方法。
# 3.2年以上C++编程工作经验，熟悉Windows和Linux开发环境，有CV算法模型工程化实战经验，如模型裁剪、模型转换、推理优化、C++ SDK封装。
# 4.良好的学习能力和沟通能力，责任心强，能够不断更新知识体系，跟踪业内前沿算法进展并进行有效改进落地。
# 5.有但不限于ncnn/tflite/mnn等移动端推理框架上模型部署经验者优先。
# 6.在CV类深度学习模型优化工作中做出突出成果者优先。
# 7.有文档版面分析相关经验者优先。
# ====================================
# {
#   "语言需求": ["python", "C++"],
#   "框架需求": ["pytorch", "tensorflow"],
#   "业务领域": [],
#   "算法与开发": ["CV模型优化", "深度学习训练框架", "模型裁剪", "模型转换", "推理优化", "SDK封装", "文档版面分析"],
#   "其他要求": ["本科及以上学历", "3年以上工作经验", "良好的学习能力", "良好的沟通能力", "责任心强", "突出成果者优先","移动端推理框架上模型部署经验者优先","文档版面分析相关经验者优先"]
# }
# 职位描述：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# =========
#  工作职责：
# 1. 进行多模态（文本与CV）方向算法研究和开发。
# 2. 负责图文的内容的标签挖掘，风险内容感知及热点分析等。
# 3. 基于大模型技术，提升风险识别效果，提升用户体验。
# 岗位要求：
# 1. 熟悉NLP、CV等相关技术，在NLP和CV方面有一定积累沉淀，有多模落地项目经验优先。
# 2. 负责多模态的算法框架构建，并基于多模态的特征表征，多模态的内容理解，提升下游风险识别任务效果。
# 3. 有扎实的编程基础，熟练掌握Tensorflow或Pytorch。
# 4. 责任心强，有良好的学习能力基团队合作精神，自我驱动力强，较强的沟通能力。
# 岗位职责：
# 1. 负责CV方向的方案设计和开发工作；
# 2. 推动CV相关算法的落地，包括模型算法的选型/训练/优化/工程化等；
# 3. 负责CV领域前沿算法研究和技术创新；
# 岗位要求：
# 1、深刻理解并掌握计算机视觉算法原理(深度学习算法/传统视觉算法)；
# 2. 具备扎实的编程基础，较强的算法实现能力，可以快速验证idea；
# 3. 在下列领域有实际项目经验：图像处理、人脸/人像、OCR、图像分类/检测/分割、多任务/多模态模型开发等；
# 4. 熟悉相关的对象检测算法（如YOLO，SSD，Faster-RCNN），有轻量化网络设计/模型压缩经验尤佳；
# 5. 有良好的团队合作意识，良好的沟通能力，优秀的逻辑分析能力以及持续学习能力。
# ====================================
# {
#     "语言需求": ["Python"],
#     "框架需求": ["TensorFlow", "PyTorch"],
#     "业务领域": [],
#     "算法与开发": ["计算机视觉算法", "深度学习算法", "传统视觉算法", "图像处理", "人脸识别", "OCR", "图像分类", "图像检测", "图像分割", "多任务模型开发", "多模态模型开发", "对象检测算法", "轻量化网络设计", "模型压缩"],
#     "其他要求": ["团队合作意识", "沟通能力", "逻辑分析能力", "持续学习能力"]
# }
# 岗位职责:
# 1.负责CV方向的创新研究项目，重点关注图像和视频的生成模型
# 2.构建新的CV pipelines，用于任务自动化 (如图像与视频的分割、打标等)
# 3.与模型团队紧密合作，设计并实施基于拟定模型架构的pipeline。
# 4.与工程团队紧密合作，探索浏览器内容创作的边界。
# 5.与产品组织的其他成员紧密合作，将机器学习模型投入到生产环境中。
# 6.与产品团队和其他工程团队协调，制定与整体公司战略一致的研究目标.
# 任职要求:
# 硕士在CV方面具有3年以上相关工程或研究经验。
# 1.精通编程，如Pvthon、C++、CUDA，以及深度学习框架，如TensorFlow和PvTorch。
# 2.具有很强的编程能力，能够编写清晰易维护的代码。
# 3.对将机器学习从研究到投入生产这一过程有着浓厚兴趣
# 4.热衷于从0到1的研究过程
# 5.具有将产品和业务目标转化为技术策略的经验
# 6.良好的沟通、合作和文档编写能力
# ====================================
# {
#   "语言需求": ["Python", "C++", "CUDA"],
#   "框架需求": ["TensorFlow", "PyTorch"],
#   "业务领域": ["内容创作", "生产环境投入", "公司战略"],
#   "算法与开发": ["图像生成模型", "CV pipelines", "深度学习框架", "机器学习模型", "技术策略"],
#   "其他要求": ["硕士学位", "3年以上相关工程或研究经验", "编程能力", "产品与业务目标转化经验", "沟通能力"]
# }
# 工作职责
# 1. 负责人脸识别和肢体检测相关算法的持续优化迭代；
# 2. 了解跟进AI/CV技术进展，推动CV算法在实际应用场景中落地。
# 任职资格
# 1. 统招本科及以上学历，计算机、数学、自动化等相关专业；
# 2. 具有扎实的图像处理和机器学习优化算法基础，有目标检测、关键点检测等方向项目落地经验，有模型部署相关经验；
# 3. 具有良好的计算机基础和编程能力，熟练使用Python语言，熟悉PyTorch/TensorFlow等深度学习框架，熟悉C/C++，有Linux平台下的开发经验；
# 4. 具有优秀的分析问题和解决问题的能力，具有良好的沟通能力和团队协作能力。
# ====================================
# {
#     "语言需求": ["Python", "C/C++"],
#     "框架需求": ["PyTorch", "TensorFlow"],
#     "业务领域": [],
#     "算法与开发": ["人脸识别", "肢体检测", "机器学习优化算法", "目标检测", "关键点检测", "模型部署"],
#     "其他要求": ["统招本科及以上学历", "计算机基础", "编程能力", "Linux平台开发经验", "沟通能力", "团队协作能力"]
# }
# AI算法工程师(CV方向)
# 薪资：60-120万/年
# 下属：6人
# 1. 负责人脸识别和肢体检测相关算法的持续优化迭代；
# 2. 了解跟进AI/CV技术进展，推动CV算法在实际应用场景中落地。
# 任职要求
# 1. 统招本科及以上学历，计算机、数学、自动化等相关专业；
# 2. 具有扎实的图像处理和机器学习优化算法基础，有目标检测、关键点检测等方向项目落地经验，有模型部署相关经验；
# 3. 具有良好的计算机基础和编程能力，熟练使用Python语言，熟悉PyTorch/TensorFlow等深度学习框架，熟悉C/C++，有Linux平台下的开发经验；
# 4. 具有优秀的分析问题和解决问题的能力，具有良好的沟通能力和团队协作能力。
# ====================================
# {
#     "语言需求": ["Python", "C/C++"],
#     "框架需求": ["PyTorch", "TensorFlow"],
#     "业务领域": [],
#     "算法与开发": ["人脸识别", "肢体检测", "图像处理", "机器学习优化算法", "目标检测", "关键点检测", "模型部署"],
#     "其他要求": ["统招本科及以上学历", "计算机、数学、自动化等相关专业", "Linux平台下的开发经验"]
# }
# 工作职责:
# 1.负责计算机视觉算法的技术研发，如图像识别、目标检测和图像分割等
# 2.参与OCR算法的研发，如图像预处理、文字检测和识别、版面分析等
# 3.参与深度学习前沿算法的研究，侧重CV大模型/多模态方向的研究
# 4.负责算法实现和工程应用落地、调试和维护
# 5.负责相关算法产品化开发、部署及性能优化
# 任职要求:
# 1.熟练掌握Linux环境编程，精通Python / C++中至少一种编程语言；
# 2.具备良好的文档编写能力、语言组织能力、沟通和协调能力、抗压能力，具有团队合作精神；
# 3.熟悉Pytorch、Tensorflow等深度学习框架。对算法有深刻的理解，并有实际项目应用经验；
# 4.熟悉使用相关的图像处理库；
# 加分项：
# 1.发表过高水平学术论文或发明专利的优先；
# 2.有OCR识别项目和CV大模型项目经验者优先；
# 3.有相关大中型开源项目者优先
# ====================================
# {
#     "语言需求": ["Python", "C++"],
#     "框架需求": ["PyTorch", "Tensorflow", "图像处理库"],
#     "业务领域": [],
#     "算法与开发": ["计算机视觉", "深度学习", "图像识别", "目标检测", "图像分割", "OCR", "文字检测", "版面分析", "大模型", "多模态"],
#     "其他要求": ["Linux环境编程", "文档编写", "沟通能力", "团队合作"]
# }
# 1、从事智能文档处理的算法研发和应用，完成文档的版面分析，如标题、表格、公式、印章等要素的抽取，优化模型，提高模型准确率及处理效率；
# 2、追踪学术界和工业界深度学习的研究和应用成功案例，并移植应用到业务场景中。
# 任职要求：
# 1、研究生及以上学历，计算机及相关专业，熟悉Python语言，有较强的编码能力，熟悉Linux开发环境，能根据业务场景需求快速学习新的深度学习框架；
# 2、在机器学习方面具有扎实的基础；
# 3、满足以下至少一个条件：
# * OCR性能优化及相关应用场景的开发经验；
# * 图像识别/分类应用场景开发经验，可根据需求进行数据标注和模型训练优化；
# * 表格抽取开发经验；
# * PDF等格式文档的版面分析经验；
# 4、参加过cv相关的相关比赛并获奖或在cv相关领域发表过顶刊论文优先考虑
# ====================================
# {
#   "语言需求": ["Python"],
#   "框架需求": ["深度学习框架", "TensorFlow", "PyTorch"],
#   "业务领域": ["智能文档处理", "深度学习", "OCR性能优化"],
#   "算法与开发": ["版面分析", "表格抽取", "图像识别", "模型训练优化", "PDF版面分析"],
#   "其他要求": ["研究生及以上学历", "Linux开发环境", "竞赛获奖", "顶刊论文发表"]
# }
# 1、从事智能文档处理的算法研发和应用，完成文档的版面分析，如标题、表格、公式、印章等要素的抽取，优化模型，提高模型准确率及处理效率；
# 2、追踪学术界和工业界深度学习的研究和应用成功案例，并移植应用到业务场景中。
# 任职要求：
# 1、研究生及以上学历，计算机及相关专业，熟悉Python语言，有较强的编码能力，熟悉Linux开发环境，能根据业务场景需求快速学习新的深度学习框架；
# 2、在机器学习方面具有扎实的基础；
# 3、满足以下至少一个条件：
# * OCR性能优化及相关应用场景的开发经验；
# * 图像识别/分类应用场景开发经验，可根据需求进行数据标注和模型训练优化；
# * 表格抽取开发经验；
# * PDF等格式文档的版面分析经验；
# 4、参加过cv相关的相关比赛并获奖或在cv相关领域发表过顶刊论文优先考虑
# =========
#  岗位职责：
# 1、从事智能文档处理的算法研发和应用，完成文档的版面分析，如标题、表格、公式、印章等要素的抽取，优化模型，提高模型准确率及处理效率；
# 2、追踪学术界和工业界深度学习的研究和应用成功案例，并移植应用到业务场景中。
# 任职要求：
# 1、研究生及以上学历，计算机及相关专业，熟悉Python语言，有较强的编码能力，熟悉Linux开发环境，能根据业务场景需求快速学习新的深度学习框架；
# 2、在机器学习方面具有扎实的基础；
# 3、满足以下至少一个条件：
# * OCR性能优化及相关应用场景的开发经验；
# * 图像识别/分类应用场景开发经验，可根据需求进行数据标注和模型训练优化；
# * 表格抽取开发经验；
# * PDF等格式文档的版面分析经验；
# 4、参加过cv相关的相关比赛并获奖或在cv相关领域发表过顶刊论文优先考虑
# 职位描述
# 1. 负责应用NLP/CV/多模态等相关技术，理解用户生产的内容，技术方向包括但不限于: 图文和视频等内容类型的打标分类、内容质量打标、热点发现、评论分析等；
# 2. 预训练模型研究，在NLP或CV等方向，训练大规模预训练模型，为下游各种业务场景算法提供增量价值。
# 职位要求
# 1. 自然语言处理、推荐、机器学习、计算机视觉、人工智能等相关专业的硕士生/博士生，在NLP或者推荐等领域有项目经验者优先；
# 2. 熟练掌握Tensorflow或Pytorch等编程框架, 熟悉C++/Python中至少一门语言，有扎实的编程基础；
# 3. 在人工智能相关的各类国际会议/期刊中发表过论文者优先，ACM等竞赛获奖者优先；
# 4. 较强的沟通、协作能力，保持好奇心，终身学习，能发现新机会，将业界新技术落地在实际业务场景。
# ====================================
# {
#   "语言需求": ["自然语言处理", "推荐", "机器学习", "计算机视觉", "人工智能", "C++", "Python"],
#   "框架需求": ["Tensorflow", "Pytorch"],
#   "业务领域": [],
#   "算法与开发": ["NLP", "CV", "预训练模型", "图文和视频分类", "内容质量打标", "热点发现", "评论分析"],
#   "其他要求": ["硕士生", "博士生", "项目经验", "国际会议/期刊论文", "竞赛获奖", "沟通能力", "协作能力", "好奇心", "终身学习"]
# }
# 岗位职责：
# 1）CV算法相关领域SDK开发与维护 ;
# 2）CV相关算子加速优化；
# 3）协助芯片架构设计与底层驱动开发工作；
# 职位要求：
# 1）本科及以上学历，计算机或电子工程等相关专业 ，2年以上工作经验;
# 2）熟练使用C/C++编程，有扎实的编程基础、良好的编程风格和工作习惯；
# 3）熟悉传统图像处理分析、计算机视觉算法的常用方法;
# 4）有计算机视觉算法 相关组件 或 SDK引擎 开发经验，优先考虑 ；
# 5）熟悉计算机体系结构，有并行计算或底层算法优化经验（如cuda，opencl，以及DSP/ARM/CPU 平台 算法加速优化），优先考虑；
# 6）具有独立解决问题的能力，良好的团队合作意识和沟通能力；
# ====================================
# {
#     "语言需求": ["C/C++"],
#     "框架需求": [],
#     "业务领域": [],
#     "算法与开发": ["计算机视觉算法", "图像处理分析", "SDK开发", "算子加速优化", "计算机体系结构", "并行计算", "底层算法优化"],
#     "其他要求": ["本科及以上学历", "计算机或电子工程等相关专业", "2年以上工作经验", "团队合作意识", "沟通能力", "独立解决问题能力"]
# }
# 岗位职责：
# 1、跟踪人工智能领域最新研究成果，负责视觉感知与自然语言、语音等感知模块相融合的算法研究；
# 2、融合机器视觉与自然语言处理、语音技术，针对文本、图像、音视频等多模态信息进行联合解析，构建计算模型，实现视觉与语言信息中的语义识别与整合，应用于图像描述、视觉问答、逻辑推理等AI领域重要任务；
# 3、研发基于单目、双目、多目相机的三维重建算法开发与优化；
# 4、优化计算机视觉基础模块效果，包括不限于语义分割、目标检测/跟踪、行为识别、位姿估计等。
# 岗位要求：
# 1、硕士及以上学历，具有扎实的CV理论基础，熟悉相关领域算法；
# 2、有3D视觉、图像处理、视频理解等领域的研究背景和工作经验者优先；
# 3、扎实的算法基础，熟悉主流深度学习框架（tensorflow / pytorch 等），具备良好的编程能力（Python / C++ / Lua等）。
# ====================================
# {
#   "语言需求": ["Python", "C++", "Lua"],
#   "框架需求": ["TensorFlow", "PyTorch"],
#   "业务领域": ["人工智能", "机器视觉", "自然语言处理"],
#   "算法与开发": ["视觉感知", "语言信息", "三维重建"],
#   "其他要求": ["硕士及以上学历", "深度学习框架熟练应用", "算法研究背景和工作经验优先"]
# }
# CV方向，文生图和图生图的，要熟悉扩散模型Diffusion和GAN
# 岗位职责：
# 1、扩散模型（以 Stable Diffusion 为主）训练和优化
# 2、负责端到端图像生成框架设计，根据稿定业务规划储备 AI 技术
# 3、推动基础模型在稿定各个产品线落地
# 岗位要求：
# 1、计算机、数学等相关专业硕士，具有扎实的计算机视觉或机器学习算法基础，在相关方向知名国际会议发表过论文
# 2、熟悉 VAE,GAN,Stable Diffusion 等基础生成模型
# 3、熟悉 CLIP,ERNIE-ViL 等 transformer 跨模态模型
# 4、熟练使用主流 LLM 并了解其原理
# 5、对稿定的业务场景有浓厚兴趣
# ====================================
# {
#   "语言需求": [],
#   "框架需求": ["Stable Diffusion", "VAE", "GAN", "CLIP", "ERNIE-ViL", "LLM"],
#   "业务领域": ["计算机视觉", "机器学习", "跨模态模型"],
#   "算法与开发": ["扩散模型训练", "图像生成框架设计", "AI 技术储备", "基础模型落地", "国际会议论文发表"],
#   "其他要求": ["计算机、数学等相关专业硕士", "浓厚的业务场景兴趣"]
# }
# 职位描述
# 1，从超级充电场站大量的视频信息中，挖掘出业务相关信息，为用户提供智能快捷的充电服务；
# 2，利用cv感知技术，大模型GPT技术等先进AI模型，建立多模态感知决策模型，为超级充电场站的用电安全，用电便利性提供可靠，智能的算法服务，为边缘端智能感知提供高performance model；
# 3，为场站空间做智能决策,视频场景挖掘,物体识别,语义分割等,提供生产级模型推理开发支持以及最前沿模型预研储备。
# 职位要求
# 1，计算机（机器学习，人工智能，信息检索方向）应用数学，统计学相关专业研究生及以上；
# 2，熟悉linux下的代码开发，熟悉pytorch，tensorflow等AI模型开发工具；
# 3，具备良好的编程能力和代码风格，熟练掌握python，熟悉大模型pre-training原理，能够熟练运用多模态大模型fine-tuning技术，对大模型进行业务微调；
# 4，掌握常用的视觉感知算法如：cnn、opencv、resnet、transformer、yolov5、vit,GPT等熟悉常见的模型结构，有成功应用经验或者独立实现过算法者优先。
# ====================================
# {
#   "语言需求": ["Python", "Linux", "编程能力", "模型预训练", "模型微调"],
#   "框架需求": ["PyTorch", "TensorFlow", "OpenCV", "ResNet", "Transformer", "YOLOv5", "ViT", "GPT"],
#   "业务领域": [],
#   "算法与开发": ["机器学习", "人工智能", "信息检索", "大模型", "多模态", "模型结构", "视觉感知算法", "模型推理开发", "模型预研"],
#   "其他要求": ["研究生及以上学历", "代码开发", "算法应用经验"]
# }
# "岗位职责
# 1. 负责整个公司AICG相关业务CV相关算法工作；
# 2. 利用机器学习、计算机视觉技术优化图像检索、图像语义理解等相关工作。
# 岗位要求
# 1. 本科及以上学历，1~5年工作经验，有计算机视觉相关的工作经验,有diffusion model等图像大模型相关经验
# 2. 优秀的分析问题和解决问题的能力，对解决具有挑战性问题充满激情；
# 3. 熟练掌握计算机视觉的算法和技术，熟悉扩散模型，有生成经验；
# 4. 熟悉Tensorflow/MxNet/Pytorch/OpenCV等机器学习和计算机视觉框架。"
# ====================================
# {
#   "语言需求": [],
#   "框架需求": ["TensorFlow", "MxNet", "Pytorch", "OpenCV"],
#   "业务领域": ["计算机视觉"],
#   "算法与开发": ["机器学习", "计算机视觉技术", "图像检索", "图像语义理解", "扩散模型", "生成经验"],
#   "其他要求": ["本科及以上学历", "1~5年工作经验", "分析问题和解决问题能力", "具有挑战性问题", "激情", "熟悉计算机视觉算法和技术"]
# }
# 职位描述
# 1，从超级充电场站大量的视频信息中，挖掘出业务相关信息，为用户提供智能快捷的充电服务；
# 2，利用cv感知技术，大模型GPT技术等先进AI模型，建立多模态感知决策模型，为超级充电场站的用电安全，用电便利性提供可靠，智能的算法服务，为边缘端智能感知提供高performance model；
# 3，为场站空间做智能决策,视频场景挖掘,物体识别,语义分割等,提供生产级模型推理开发支持以及最前沿模型预研储备。
# 职位要求
# 1，计算机（机器学习，人工智能，信息检索方向）应用数学，统计学相关专业研究生及以上；
# 2，熟悉linux下的代码开发，熟悉pytorch，tensorflow等AI模型开发工具；
# 3，具备良好的编程能力和代码风格，熟练掌握python，熟悉大模型pre-training原理，能够熟练运用多模态大模型fine-tuning技术，对大模型进行业务微调；
# 4，掌握常用的视觉感知算法如：cnn、opencv、resnet、transformer、yolov5、vit,GPT等熟悉常见的模型结构，有成功应用经验或者独立实现过算法者优先。
# =========
#  岗位职责：
# 1，从超级充电场站大量的视频信息中，挖掘出业务相关信息，为用户提供智能快捷的充电服务；
# 2，利用cv感知技术，大模型GPT技术等先进AI模型，建立多模态感知决策模型，为超级充电场站的用电安全，用电便利性提供可靠，智能的算法服务，为边缘端智能感知提供高performance model；
# 3，为场站空间做智能决策,视频场景挖掘,物体识别,语义分割等,提供生产级模型推理开发支持以及前沿模型预研储备。
# 任职要求：
# 1，计算机（机器学习，人工智能，信息检索方向）应用数学，统计学相关专业研究生及以上；
# 2，熟悉linux下的代码开发，熟悉pytorch，tensorflow等AI模型开发工具；
# 3，具备良好的编程能力和代码风格，熟练掌握python，熟悉大模型pre-training原理，能够熟练运用多模态大模型fine-tuning技术，对大模型进行业务微调；
# 4，掌握常用的视觉感知算法如：cnn、opencv、resnet、transformer、yolov5、vit,GPT等熟悉常见的模型结构，有成功应用经验或者独立实现过算法者优先。
# "岗位职责
# 1. 负责整个公司AICG相关业务CV相关算法工作；
# 2. 利用机器学习、计算机视觉技术优化图像检索、图像语义理解等相关工作。
# 岗位要求
# 1. 本科及以上学历，1~5年工作经验，有计算机视觉相关的工作经验,有diffusion model等图像大模型相关经验
# 2. 优秀的分析问题和解决问题的能力，对解决具有挑战性问题充满激情；
# 3. 熟练掌握计算机视觉的算法和技术，熟悉扩散模型，有生成经验；
# 4. 熟悉Tensorflow/MxNet/Pytorch/OpenCV等机器学习和计算机视觉框架。"
# =========
#  "岗位职责
# 1. 负责整个公司AICG相关业务CV相关算法工作；
# 2. 利用机器学习、计算机视觉技术优化图像检索、图像语义理解等相关工作。
# 岗位要求
# 1. 本科及以上学历，1~5年工作经验，有计算机视觉相关的工作经验；
# 2. 优秀的分析问题和解决问题的能力，对解决具有挑战性问题充满激情；
# 3. 熟练掌握计算机视觉的算法和技术，熟悉扩散模型，有生成经验；
# 4. 熟悉Tensorflow/MxNet/Pytorch/OpenCV等机器学习和计算机视觉框架。"
# 工作职责：
# 1.负责计算机视觉.图像处理相关算法的研发和优化，跟进学界最新的CV算法研究，包括但不限于迁移学习、细粒度检测算法、目标的检测与分割等；
# 2.将理论模型编程实现，并将其应用于真实的业界场景；
# 3 深入分析现有算法，了解业务需求，给出有效的优化解决方案。
# 任职要求：
# 1.计算机科学，应用数学，电子工程等相关专业1-3年工作经验；
# 2.具有很强的编程实现能力，熟悉Python及OpenCV,Pillow等常用图像处理库；
# 3.掌握应用数学基础知识，熟悉统计学习，最优化理论等相关领域的基本概念和思路；
# 4.掌握计算机视觉领域的基础理论和经典算法；
# 5.有较强的动手能力和学习能力，求知欲强，对新技术有激情。有产品思维，对技术的商业落地感兴趣。
# ====================================
# {
#   "语言需求": ["Python"],
#   "框架需求": ["OpenCV", "Pillow"],
#   "业务领域": ["计算机视觉"],
#   "算法与开发": ["迁移学习", "细粒度检测算法", "目标的检测与分割", "统计学习", "最优化理论", "产品思维"],
#   "其他要求": ["计算机科学", "应用数学", "电子工程", "动手能力", "学习能力", "产品落地"]
# }
# 职责描述:
# 职责描述
# （一）、经营规划
# 1.根据营销公司医院部整体经营策略，负责制定所辖部门产品中长期策略和发展方向
# 2.围绕“一个中心，三个基本点”，负责制定所辖部门经营策略与发展规划，持续贯彻专业化的学术营销及市场推广模式，确保达成各项经营目标
# 3.整合市场资源，发挥市场策划导向功能，做好产品和学术品牌建设，促进各产品覆盖率和占有率的提升
# 4.持续做好络病理论体系和通络药物研究成果的学术推广，提升公司品牌形象，强化络病理论学术影响力
# （二）、营销管理
# 5.围绕事业部经营策略，负责策划各类推广活动和学术品牌建设项目，并负责推动实施及跟进评估
# 6.负责各类推广活动相关推广物料的设计、活动文案撰写等相关工作
# 7.负责各类客情项目/活动的设计，并推动销售团队组织实施及跟进评估工作
# 8.不断优化和丰富所辖部门KOL专家库，并做好与学会、协会等学术组织的沟通与合作
# 9.制定处方客户分级分类管理办法，做好重点客户的选择、培育、评估、维护
# 10.完善数据管理体系，不断提升对业务推进的跟踪评估水平
# 11.结合医药行业发展趋势及处方药推广模式的变化，持续创新处方药推广模式与推广方式
# （三）、团队管理
# 12.围绕“凝聚、激励、约束”六字方针，做好所辖团队的管理，营造良好的工作氛围，增强团队凝聚力
# 13.负责对下属团队进行系统的培训和工作指导，日常管理和绩效管理，加强人才梯队建设，建立高素质的市场推广团队。
# 任职要求:
# 1.本科及以上学历，医药专业；
# 2.品牌外资药企临床产品经理3年及以上任职经验，熟悉CV领域产品策划经验者优先；
# 3.有团队管理经验者优先，优秀的市场洞察力和业务规划能力，良好的组织协调能力、问题解决能力、团队协作能力及学习能力；
# 4.良好的执行力及抗压能力。
# ====================================
# {
#   "语言需求": [],
#   "框架需求": [],
#   "业务领域": ["医药专业", "CV领域产品策划", "临床产品经理"],
#   "算法与开发": [],
#   "其他要求": ["本科及以上学历", "品牌外资药企临床产品经理3年及以上任职经验", "团队管理经验", "市场洞察力", "业务规划能力", "组织协调能力", "问题解决能力", "团队协作能力", "学习能力", "执行力", "抗压能力"]
# }
# 职责描述：
# 1. 根据项目需求，负责产品和项目的APP开发工作；
# 2. 辅助完成深度学习模型在终端上的部署等工作；
# 3. 独立完成Android软件开发、验证和修正测试中发现的问题，并根据开发过程中的体验对产品提出改进建议。
# 任职要求：
# 1. 精通Android系统架构及相关技术；
# 2. 熟练使用Android Studio开发工具和API的调用，, 熟练NDK使用；
# 3. 喜欢创新，对新产品有独到的见解与认识，追求良好的用户体验；
# 4. 熟练使用java, c/c++语言，有一定算法基础；
# 5. 有手机端App开发经验者优先；
# 6. 熟悉JNI开发者优先；
# 7. 有深度学习模型手机端移植经验者优先；
# 8. 有CV/图像/视频处理经验者优先。
# 公司介绍：
# 三星电子中国研究院是三星电子在华投资设立的具有独立法人资格的研发机构，是具备博士后工作站运营资质、聚集了600人研发团队，并由国家批准认定的软件企业。研究院专注于人工智能、5G/6G通信技术研究和标准化等前沿技术，也积极进行商用化的开发、推动先进技术在三星产品中的商用化落地，提升三星电子产品的竞争力。
# 新时代，新机遇。三星电子中国研究院希望把握人工智能、5G/6G与IoT技术发展的时代机遇，凝聚海内外计算机、电子及通信领域的优秀人才，坚守“做中国人民喜爱的企业，贡献于中国社会的企业”的承诺，与您一起携手共赢、创造未来! 真诚欢迎您的加入！
# ※ 请应聘者在应聘过程中对现公司、 前公司的商业秘密进行保密
# ※ 请应聘者确认您投递的简历不包含现公司、前公司的商业秘密
# ====================================
# {
#   "语言需求": ["java", "c/c++"],
#   "框架需求": ["Android Studio", "NDK", "JNI"],
#   "业务领域": ["移动应用开发", "深度学习模型部署", "手机端移植"],
#   "算法与开发": ["Android系统架构", "深度学习模型", "CV/图像/视频处理"],
#   "其他要求": ["手机端App开发经验", "良好的用户体验追求", "有独到的见解与认识"]
# }
# 岗位职责：
# 1. 负责提出数据收集需求、整理训练数据；
# 2. 负责图像分类、目标检测等CV相关算法模型的训练与调优。
# 任职要求：
# 1. 全日制硕士及以上学历，计算机、自动化等相关专业，或本科以上且3年以上计算机视觉算法开发相关经验；
# 2. 熟悉计算机视觉理论、深度学习原理、机器学习原理；
# 3. 收集和标注过图像/视频数据，对数据工程有深刻理解；
# 4. 熟悉TensorFlow/PyTorch至少一种深度学习框架；
# 5. 熟悉图像分类和目标检测相关算法，如AlexNet、ResNet、Yolo系列等；
# 6. 有类SAM研发/应用经验者优先。
# ====================================
# {
#   "语言需求": [],
#   "框架需求": ["TensorFlow", "PyTorch"],
#   "业务领域": ["计算机视觉"],
#   "算法与开发": ["图像分类", "目标检测", "深度学习", "ResNet", "Yolo", "SAM研发"],
#   "其他要求": ["全日制硕士及以上学历", "计算机、自动化等相关专业", "本科以上且3年以上计算机视觉算法开发相关经验", "熟悉计算机视觉理论", "深度学习原理", "机器学习原理", "收集和标注过图像/视频数据", "对数据工程有深刻理解"]
# }
# 岗位描述：
# 1、负责微博基础内容AI的研发、探索，落地到微博内容理解、内容消费和内容生产的核心场景。
# 2、负责图像方向AIGC相关算法研究，熟悉GAN 、扩散模型、图像生成、多模态等方向，及周边技术（如Lora，ControlNet等）。
# 3、负责提升图像生成模型训练、推理等相关方面的性能及效果优化。
# 4、跟进AIGC方向研究前沿，使用最新技术解决实际业务问题。
# 5、有AIGC相关产品落地经验者优先。
# 岗位要求：
# 1、计算机、数学或相关专业本科及以上学历，2年及以上CV或AI相关算法研发经验
# 2、有计算机视觉任一方向研发经验，包括并不限于图像/视频分类、分割、检测、去重、跟踪，多模态理解等。
# 3、扎实的编程功底，具备较强的工程实现能力。
# 4、热爱技术，能够深入细节，对前沿的算法有了解并积极尝试，熟悉常用的机器学习技术及常用深度学习框架。
# 5、主动性好，乐于贴近业务问题，具备技术驱动、数据驱动、产品驱动等多种驱动业务思维能力。
# 6、优秀的沟通能力和合作精神，能够处理复杂环境的沟通协作
# 具备以下条件优先:
# 3、 发表过AI顶会论文、或者AI竞赛获奖者优先
# 2、有优秀AI方向开源项目者优先
# ====================================
#
# {
#   "语言需求": ["Python"],
#   "框架需求": ["TensorFlow", "PyTorch", "Keras"],
#   "业务领域": ["计算机视觉", "多模态理解"],
#   "算法与开发": ["图像生成", "GAN", "扩散模型", "图像分类", "图像分割", "目标检测", "深度学习"],
#   "其他要求": ["本科及以上学历", "2年及以上CV或AI相关算法研发经验", "发表过AI顶会论文", "AI竞赛获奖者优先", "优秀的沟通能力"]
# }
# 岗位描述：
# 1、负责微博基础内容AI的研发、探索，落地到微博内容理解、内容消费和内容生产的核心场景。
# 2、负责图像方向AIGC相关算法研究，熟悉GAN 、扩散模型、图像生成、多模态等方向，及周边技术（如Lora，ControlNet等）。
# 3、负责提升图像生成模型训练、推理等相关方面的性能及效果优化。
# 4、跟进AIGC方向研究前沿，使用最新技术解决实际业务问题。
# 5、有AIGC相关产品落地经验者优先。
# 岗位要求：
# 1、计算机、数学或相关专业本科及以上学历，2年及以上CV或AI相关算法研发经验
# 2、有计算机视觉任一方向研发经验，包括并不限于图像/视频分类、分割、检测、去重、跟踪，多模态理解等。
# 3、扎实的编程功底，具备较强的工程实现能力。
# 4、热爱技术，能够深入细节，对前沿的算法有了解并积极尝试，熟悉常用的机器学习技术及常用深度学习框架。
# 5、主动性好，乐于贴近业务问题，具备技术驱动、数据驱动、产品驱动等多种驱动业务思维能力。
# 6、优秀的沟通能力和合作精神，能够处理复杂环境的沟通协作
# 具备以下条件优先:
# 3、 发表过AI顶会论文、或者AI竞赛获奖者优先
# 2、有优秀AI方向开源项目者优先
# =========
#  岗位描述：
# 1、负责微博基础内容AI的研发、探索，落地到微博内容理解、内容消费和内容生产的核心场景。
# 2、负责图像方向AIGC相关算法研究，熟悉GAN 、扩散模型、图像生成、多模态等方向，及周边技术（如Lora，ControlNet等）。
# 3、负责提升图像生成模型训练、推理等相关方面的性能及效果优化。
# 4、跟进AIGC方向研究前沿，使用最新技术解决实际业务问题。
# 5、有AIGC相关产品落地经验者优先。
# 岗位要求：
# 1、计算机、数学或相关专业本科及以上学历，4年及以上CV或AI相关算法研发经验
# 2、熟悉常见生成模型技术，及周边技术（如Lora，ControlNet等），了解模型优化技术。
# 3、扎实的编程功底，具备较强的工程实现能力。
# 4、热爱技术，能够深入细节，对前沿的算法有了解并积极尝试，熟悉常用的机器学习技术及常用深度学习框架。
# 5、主动性好，乐于贴近业务问题，具备技术驱动、数据驱动、产品驱动等多种驱动业务思维能力。
# 6、优秀的沟通能力和合作精神，能够处理复杂环境的沟通协作
# 具备以下条件优先:
# 4、 发表过AI顶会论文、或者AI竞赛获奖者优先
# 2、有优秀AI方向开源项目者优先
# 岗位职责：
# 1.负责机器学习、计算机视觉算法的开发工作，对算法效果负责，持续优化算法性能；
# 2.负责相关算法前沿技术的研究工作；
# 3.负责相关的技术研究的专利或论文撰写。
# 任职要求：
# 1.硕士以上学历，计算机及相关专业；
# 2.两年以上机器学习/深度学习工程开发相关经验，扎实的数据结构和算法设计基础；
# 3.熟悉计算机视觉相关算法，包括但不限于目标检测/识别、OCR、图像增强（超分、去噪等）、图像分割、手势/姿态识别、Style Transfer等；
# 4.掌握一种以上开源深度学习框架，如Pytorch、TensorFlow等，具有丰富的实践经验；
# 5.精通C++或Python，掌握CUDA编程，熟悉OpenCV等计算机视觉开源代码库；
# 6.具有端侧部署开发经验者优先；有图像算法性能优化经验者优先；
# 7.有较强的自学能力、钻研精神和动手能力，具有良好的逻辑思维能力、沟通能力和团队协作能力，做事认真、踏实、负责；
# 8.有良好的英文读写能力，能阅读英文学术文献。
# ====================================
# {
#   "语言需求": ["C++", "Python", "CUDA", "OpenCV"],
#   "框架需求": ["PyTorch", "TensorFlow"],
#   "业务领域": [],
#   "算法与开发": ["机器学习", "深度学习", "计算机视觉", "目标检测", "OCR", "图像增强", "图像分割", "手势/姿态识别", "Style Transfer"],
#   "其他要求": ["硕士以上学历", "数据结构", "算法设计", "开源深度学习框架实践经验", "端侧部署开发经验", "图像算法性能优化经验", "自学能力", "逻辑思维能力", "团队协作能力", "英文读写能力"]
# }
# - 职位描述
# - 完成SOC芯片在硅前原型验证（FPGA/EMU），硅后bringup到量产的板级调试和系统验证
# - 定义系统级验证和测试标准，帮助产品快速、顺利量产，适配不同类型的测试，完成包括功能测试、兼容性测试、性能测试、压力测试、可靠性测试等测试
# - 移植操作系统，开发底层驱动，测试用例，测试工具和脚本
# - 分析和解决从Bringup到量产过程中发现的各种问题，并进行性能优化
# - 对故障芯片进行问题分析，协助产线提高良率
# - 任职资格
# - 本科及以上学历
# - 熟练掌握C语言及汇编语言，熟练使用python/tcl等脚本
# - 熟悉ARM/RISC-V CPU体系结构
# - 熟悉Linux/freertos等操作系统
# - 熟悉高速接口驱动开发及调试
# - 熟悉Palladium/Zebu/Haps原型平台使用及开发
# - -有芯片Bringup经验或者芯片量产经验的优先
# - -熟练掌握测试仪器如示波器、协议分析仪的优先
# - -有AI训练，推理芯片相关经验的优先
# ====================================
# {
#     "语言需求": ["C语言", "汇编语言", "python", "tcl"],
#     "框架需求": [],
#     "业务领域": [],
#     "算法与开发": ["系统级验证", "系统测试", "底层驱动开发", "ARM架构", "RISC-V架构", "操作系统移植", "高速接口驱动开发", "Palladium", "Zebu", "Haps原型平台", "芯片Bringup", "芯片量产", "测试仪器", "协议分析"],
#     "其他要求": ["本科及以上学历", "AI训练", "推理芯片相关经验"]
# }
# 工作职责
# 1、从事大语言模型的研究、训练和应用，包括但不限于行业知识的注入、通用能力提升、训练算法优化、多模态技术等；
# 2、跟进和分享领域内前沿技术，快速实验进行复现，找到合适的方法解决或优化业务问题；
# 3、负责支持集团的业务智能化需求，针对具体业务场景进行算法设计和研发，包括但不限于大语言模型应用、预测、推荐、运筹优化等相关需求。
# 任职资格
# 1、计算机、软件工程、电子与通信等相关专业硕士及以上学历，5年以上算法相关工作经验；
# 2、熟悉主流的深度学习开发框架，有大规模算法设计与研发经验，有较强的编程能力，有相关项目实践经验；
# 3、良好的自驱能力、业务敏感度，协作沟通能力及团队合作意识强；
# 4、有人工智能相关顶会论文者优先。
# ====================================
#
# {
#   "语言需求": ["计算机", "软件工程", "电子与通信", "深度学习", "自然语言处理", "多模态技术"],
#   "框架需求": ["深度学习开发框架"],
#   "业务领域": ["业务智能化", "预测", "推荐"],
#   "算法与开发": ["大语言模型", "算法设计", "研发经验", "项目实践经验"],
#   "其他要求": ["硕士及以上学历", "5年以上工作经验", "编程能力", "自驱能力", "团队合作意识", "人工智能相关顶会论文"]
# }
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# ====================================
# {
#   "语言需求": ["Python", "C++", "Java"],
#   "框架需求": ["TensorFlow", "PyTorch", "OpenCV"],
#   "业务领域": ["医疗", "互联网医疗", "健康"],
#   "算法与开发": ["计算机视觉", "NLP", "深度学习"],
#   "其他要求": ["硕士及以上学历", "编码能力", "英文文献阅读能力"]
# }
# 岗位职责：
# 1.负责计算机视觉在3D空间的算法的开发工作，对算法效果负责，持续优化算法性能；
# 2.负责3D重建及3D建模优化所需的AI技术探索、研究与应用；
# 3.负责相关算法前沿技术的研究工作；
# 4.负责相关的技术研究的专利或论文撰写。
# 任职要求：
# 1.硕士以上学历，博士学历优先，硕士3年以上相关工作经验；
# 2.精通计算机3D视觉感知理论、技术体系、算法，如LiDAR、SLAM、多视图几何、深度估计、相机姿态估计、特征配准等；
# 3.熟悉3D建模的AI实现方法，如Nerf、3DNerf、ICON、SMPL、STAR等；
# 4.精通计算机图像处理，包括但不限于目标检测/识别、图像增强（超分、去噪等）、图像分割、手势/姿态识别、Style Transfer等；
# 5.掌握一种以上开源深度学习框架，如Pytorch、TensorFlow等，具有丰富的实践经验；
# 6.精通C++或Python，掌握CUDA编程，熟悉OpenCV、Eigen等计算库；
# 7.具有端侧部署开发经验者优先；有图像算法性能优化经验者优先；
# 8.有较强的自学能力、钻研精神和动手能力，具有良好的逻辑思维能力、沟通能力和团队协作能力，做事认真、踏实、负责；
# 9.有良好的英文读写能力，能阅读英文学术文献，能复现论文中的算法。
# 10.有主流3D建模软件使用经验者优先。
# ====================================
# {
#   "语言需求": ["C++", "Python", "CUDA", "OpenCV", "Eigen"],
#   "框架需求": ["PyTorch", "TensorFlow"],
#   "业务领域": [],
#   "算法与开发": [
#     "计算机视觉",
#     "3D空间算法",
#     "3D重建",
#     "3D建模优化",
#     "深度学习",
#     "LiDAR",
#     "SLAM",
#     "多视图几何",
#     "深度估计",
#     "相机姿态估计",
#     "特征配准",
#     "计算机图像处理",
#     "目标检测",
#     "图像增强",
#     "图像分割",
#     "手势识别",
#     "姿态识别",
#     "Style Transfer",
#     "端侧部署开发",
#     "图像算法性能优化"
#   ],
#   "其他要求": ["硕士学历", "博士学历优先", "3年以上相关工作经验", "英文读写能力", "学术文献阅读", "良好的逻辑思维能力", "沟通能力", "团队协作能力", "自学能力", "钻研精神", "动手能力", "负责任", "主流3D建模软件使用经验"]
# }
# 职位详情：
# 1、负责手机相册场景下人脸语义分析方向的模型研发和迭代，包含人脸聚类，人脸颜值识别、人脸质量识别，人物关系识别，人脸跨年龄（儿童人脸识别）、跨肤色特征提取（多肤色人脸识别），服装特征提取，人脸生成等；
# 2、对上述算法进行轻量化研究以满足端侧部署要求；参与、推动技术落地到多个相册产品中。
# 3、探索大模型、生成模型、多模态、自监督等前沿技术；
# 职位要求
# 1、在计算机视觉某个领域有较深入的研究，包括但不限于：人脸识别、人脸聚类、AIGC、多模态预训练、人脸3DMM、神经辐射场、transformer模型等；
# 2、对深度学习算法有深刻理解，熟悉常用深度学习框架；
# 3、快速学习新技术的能力，能够在较短时间内理解前沿论文并评价；
# 4、有成果发表在CVPR、ICCV、ECCV、ICML、TPAMI等国际顶会顶刊者优先；在计算机视觉知名竞赛取得优异名次者优先；有高质量Github项目经验者优先；
# 5、积极主动有热情，能与团队合作相处，具备较强的沟通能力。
# ====================================
# {
#   "语言需求": [],
#   "框架需求": ["深度学习框架", "transformer模型"],
#   "业务领域": ["计算机视觉", "人脸识别", "人脸聚类"],
#   "算法与开发": ["计算机视觉算法", "深度学习算法", "轻量化研究", "大模型探索", "生成模型研究", "多模态技术探索", "自监督学习"],
#   "其他要求": ["国际顶会发表论文", "知名竞赛优异名次", "高质量Github项目经验", "沟通能力"]
# }
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# =========
#  工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 薪资待遇：20-40K，16薪
# 薪资待遇：底薪30-50K/月，16薪/年，五险一金，每个工作日30元餐补随工资发放
# 职责描述：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职要求：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# ====================================
# {
#     "语言需求": ["Python", "C++", "Java"],
#     "框架需求": ["TensorFlow", "PyTorch", "OpenCV"],
#     "业务领域": ["医疗健康领域"],
#     "算法与开发": ["计算机视觉", "NLP", "深度学习算法"],
#     "其他要求": ["人工智能相关专业硕士及以上学历", "医疗健康领域的工作或研究经验", "快速阅读英文文献", "自我驱动力强"]
# }
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 薪资待遇：20-40K，16薪
# =========
#  工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 岗位职责：
# 1.负责计算机视觉在3D空间的算法的开发工作，对算法效果负责，持续优化算法性能；
# 2.负责3D重建及3D建模优化所需的AI技术探索、研究与应用；
# 3.负责相关算法前沿技术的研究工作；
# 4.负责相关的技术研究的专利或论文撰写。
# 任职要求：
# 1.硕士以上学历，博士学历优先，硕士3年以上相关工作经验；
# 2.精通计算机3D视觉感知理论、技术体系、算法，如LiDAR、SLAM、多视图几何、深度估计、相机姿态估计、特征配准等；
# 3.熟悉3D建模的AI实现方法，如Nerf、3DNerf、ICON、SMPL、STAR等；
# 4.精通计算机图像处理，包括但不限于目标检测/识别、图像增强（超分、去噪等）、图像分割、手势/姿态识别、Style Transfer等；
# 5.掌握一种以上开源深度学习框架，如Pytorch、TensorFlow等，具有丰富的实践经验；
# 6.精通C++或Python，掌握CUDA编程，熟悉OpenCV、Eigen等计算库；
# 7.具有端侧部署开发经验者优先；有图像算法性能优化经验者优先；
# 8.有较强的自学能力、钻研精神和动手能力，具有良好的逻辑思维能力、沟通能力和团队协作能力，做事认真、踏实、负责；
# 9.有良好的英文读写能力，能阅读英文学术文献，能复现论文中的算法。
# 10.有主流3D建模软件使用经验者优先。
# =========
#  岗位职责：
# 1.负责计算机视觉在3D空间的算法的开发工作，对算法效果负责，持续优化算法性能；
# 2.负责3D重建及3D建模优化所需的AI技术探索、研究与应用；
# 3.负责相关算法前沿技术的研究工作；
# 4.负责相关的技术研究的专利或论文撰写。
# 任职要求：
# 1.硕士以上学历，博士学历优先，硕士3年以上相关工作经验；
# 2.精通3D人体建模的AI实现方法，如Nerf、3DNerf、ICON、SMPL、STAR等；
# 3.熟悉计算机3D视觉感知理论、技术体系、算法，如LiDAR、SLAM、多视图几何、深度估计、相机姿态估计、特征配准等；
# 4.精通计算机图像处理，包括但不限于目标检测/识别、图像增强（超分、去噪等）、图像分割、手势/姿态识别、Style Transfer等；
# 5.掌握一种以上开源深度学习框架，如Pytorch、TensorFlow等，具有丰富的实践经验；
# 6.精通C++或Python，掌握CUDA编程，熟悉OpenCV等计算库；
# 7.具有端侧部署开发经验者优先；有3D数字人产品研发经验者优先；
# 8.有较强的自学能力、钻研精神和动手能力，具有良好的逻辑思维能力、沟通能力和团队协作能力，做事认真、踏实、负责；
# 9.有良好的英文读写能力，能阅读英文学术文献，能复现论文中的算法。
# 10.有主流3D建模软件使用经验者优先。
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# =========
#  工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 薪资待遇：20-40K，16薪
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 薪资待遇：20-40K，16薪
# =========
#  工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 薪资待遇：20-40K，16薪
# =========
#  工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 薪资待遇：20-40K，16薪
# =========
#  工作职责：
# 1. 用计算机视觉及NLP等技术实现医疗相关数据的结构化，并对数据潜在关系和价值进行挖掘；
# 2. 参与图像识别、目标检测、图像分割、文本分类及理解等算法的开发；
# 3. 构建通用的分布式机器学习系统，快速支持算法应用；
# 4. 探索AI技术在互联网医疗及健康领域的应用落地。
# 任职资格：
# 1.计算机、人工智能及应用数学等相关专业硕士及以上学历，有较好的理论基础和快速学习能力；
# 2.熟悉TensorFlow/PyTorch/OpenCV等机器学习和计算机视觉框架；
# 3.对常用的机器学习/深度学习算法和模型有深入理解，如：LR/CRF/CNN/RNN/Transformer等；
# 4.具备优秀的编码能力、扎实的数据结构和算法功底；熟悉 Linux 开发环境，掌握至少一门编程和脚本语言，如 Python、C++、Java等；
# 5.有计算机视觉及NLP领域的工作或研究经验，能快速阅读前沿英文文献，并依据具体场景进行落地优化；
# 6.踏实稳重，乐观向上，自我驱动力强，对医疗健康领域感兴趣，具备敏锁的洞察力和良好的抗压能力。
# 1、负责公司核⼼产品的销售全链路转化率提升相关数据
# 分析和算法⼯作，不限于⽤⼾画像、⽤⼾增⻓、销量预测、派单调度等；
# 1、负责公司制造和物流供应链环节的智能化算法研究和
# 开发，不限于视觉检测定位、机械臂运动、运筹优化等；
# 3、从业务需求出发，通过数据分析和智能算法设计，跟
# 进具体业务场景策略⽅案的设计与上线，对策略效果负责；
# 4、探索⽣成式⼤模型在⼯业界的落地场景，建⽴企业内
# 部领域⼤模型并推⼴应⽤；
# ====================================
# {
#     "语言需求": [],
#     "框架需求": [],
#     "业务领域": [
#         "销售全链路转化率",
#         "制造和物流供应链",
#         "⼯业界的落地场景"
#     ],
#     "算法与开发": [
#         "⽤⼾画像",
#         "⽤⼾增⻓",
#         "销量预测",
#         "派单调度",
#         "视觉检测定位",
#         "机械臂运动",
#         "运筹优化",
#         "⽣成式⼤模型"
#     ],
#     "其他要求": []
# }
# 岗位职责：
# 1.负责AIGC内容生成与创作相关算法的开发工作，对算法效果负责，持续优化算法性能；
# 2.跟踪AIGC技术发展，解决面向不同应用场景的视频、图像、文本的生成问题；
# 3.负责相关算法前沿技术的研究工作；
# 4.负责复杂内容生成的研究，包括prompt设计、风格控制、主题控制、一致性等。
# 任职要求：
# 1.硕士以上学历，博士学历优先，硕士3年以上相关工作经验；
# 2.熟悉主流大模型原理及应用场景，精通图像、视频生成技术（如StyleGAN、CLIP、Stable Diffusion、DALL-E等）；
# 3.精通计算机视觉相关算法，包括但不限于目标检测/识别、图像增强（超分、去噪等）、图像分割、手势/姿态识别、Style Transfer等；
# 4.熟悉计算机视觉感知理论、技术体系、算法；
# 5.掌握一种以上开源深度学习框架，如Pytorch、TensorFlow等，具有丰富的实践经验；
# 6.精通C++或Python，掌握CUDA编程，熟悉OpenCV等计算机视觉开源代码库；
# 7.具有端侧部署开发经验者优先；有数字人研发经验者优先；
# 8.有较强的自学能力、钻研精神和动手能力，具有良好的逻辑思维能力、沟通能力和团队协作能力，做事认真、踏实、负责；
# 9.有良好的英文读写能力，能阅读英文学术文献。
# ====================================
# {
#   "语言需求": ["C++", "Python", "CUDA", "英文"],
#   "框架需求": ["PyTorch", "TensorFlow", "OpenCV"],
#   "业务领域": [],
#   "算法与开发": ["图像生成", "计算机视觉", "目标检测", "图像增强", "图像分割", "手势识别", "姿态识别", "Style Transfer", "深度学习"],
#   "其他要求": ["硕士学历", "博士学历优先", "3年以上相关工作经验", "自学能力", "逻辑思维能力", "沟通能力", "团队协作能力", "英文读写能力"]
# }
# 职位描述：
# 1. 负责基于计算机视觉/多模态技术的高精度、高质量地图POI数据的自动化生产和实时更新；
# 2. 负责研究和开发感知/识别等相关前沿技术，包括但不限于2D/3D目标检测、分割、匹配、深度估计、位姿估计等；
# 3. 参与其他创新应用预研。
# 职位要求：
# 1. 具备扎实的数学和计算机科学基础，具备良好的团队合作精神和沟通能力，熟练掌握计算机视觉领域的基础理论和方法；
# 2. 在一个或多个视觉应用领域有深入研究，如图像分类、2D/3D目标检测、目标分割、目标跟踪、BEV感知、自监督学习等；
# 3. 熟悉MLP、CNN、Transformer等网络架构；
# 4. 有较强的编程实现能力，熟练掌握Python，熟悉linux下开发环境，熟练掌握PyTorch等至少一种深度学习框架；
# 5. 具有快速学习能力，善于通过查阅文献资料解决问题。
# 具有以下者优先：
# 1. 在计算机视觉领域内的权威期刊（TPMAI/IJCV/TIP等）或顶级会议（CVPR/ICCV/ECCV等）发表过文章；
# 2. 在计算机视觉的通用或细分领域的权威竞赛中取得前三名；
# 3. 有机器学习/计算机视觉开源社区贡献；
# 4. 有模型压缩优化经验（剪枝、量化和蒸馏）；
# 5. 具备3D目标检测、BEV感知实践经验。
# =========
#  1. 负责基于计算机视觉/多模态技术的高精度、高质量地图POI数据的自动化生产和实时更新； 2. 负责研究和开发感知/识别等相关前沿技术，包括但不限于2D/3D目标检测、分割、匹配、深度估计、位姿估计等； 3. 参与其他创新应用预研。
# 任职要求：
# 1. 具备扎实的数学和计算机科学基础，具备良好的团队合作精神和沟通能力，熟练掌握计算机视觉领域的基础理论和方法； 2. 在一个或多个视觉应用领域有深入研究，如图像分类、2D/3D目标检测、目标分割、目标跟踪、BEV感知、自监督学习等； 3. 熟悉MLP、CNN、Transformer等网络架构； 4. 有较强的编程实现能力，熟练掌握Python，熟悉linux下开发环境，熟练掌握PyTorch等至少一种深度学习框架； 6. 具有快速学习能力，善于通过查阅文献资料解决问题。 具有以下者优先： 1. 在计算机视觉领域内的权威期刊（TPMAI/IJCV/TIP等）或顶级会议（CVPR/ICCV/ECCV等）发表过文章； 2. 在计算机视觉的通用或细分领域的权威竞赛中取得前三名； 3. 有机器学习/计算机视觉开源社区贡献； 4. 有模型压缩优化经验（剪枝、量化和蒸馏）； 5. 具备3D目标检测、BEV感知实践经验
# 化妆品备案优秀技术主管：
# 1、 岗位描述：
# （1） 负责联系、解答客户咨询获取化妆品申报备案与注册业务；
# （2） 负责全程运作化妆品申报流程，制定申报方案；
# （3） 安排实验室，制定试验规划，审核试验计划书、试验报告；
# （4） 负责建立并维护与相关登记注册机构、实验室、行业之间良好的工作往来；
# （5） 负责起草化妆品申报部门的宣传稿、及时更新网站内容；
# （6） 负责内部培训及协调，协助公司其他登记部门工作，对制定、安排试验规划提出合理化建议，帮助选择、联系实验室；
# （7） 完成公司领导交办的其他任务。
# 2、 职位要求：
# （1） 食品、医药、化工等相关专业正规院校本科以上学历；
# （2） 3年以上化妆品备案等从业经验；
# （3） 良好的英文听说读写能力，能够独立阅览英文网站，翻译资料，熟练使用办公软件；
# （4） 熟知化妆品相关法律法规和登记注册资料准备的相关流程；
# （5） 对公对私公正公平，职业素养确实高崇，少有化妆品行业一般负面习惯于习气；
# （7） 反应敏捷，思路清晰，工作细致，责任心强，勇承担挑战性工作，具有敬业精神和较强的团队意识；
# ====================================
# {
#   "语言需求": ["英文"],
#   "框架需求": [],
#   "业务领域": ["化妆品备案"],
#   "算法与开发": [],
#   "其他要求": ["食品", "医药", "化工", "法律法规", "素质要求", "学历要求", "从业经验", "职业素养", "反应敏捷", "责任心", "团队意识"]
# }
# 工作职责
# 1. 负责人脸身份认证领域算法模型研发，包括但不限于：人脸活体检测、人脸识别、人脸质量评估、人脸关键点检测、 图像加密、图像处理等方向的深度学习模型实际研发经验，具有炫彩活检研发经验者优先。 2. 负责深度学习模型压缩、模型剪枝等研发工作，具有便携终端轻量级模型研发经验者优先。 3. 负责跟踪上述领域的先进技术及研发工作。 4. 负责相关算法模型的产线开发、验证、优化及维护等产线工作。
# 任职要求
# 1. 计算机相关专业，大学本科毕业，硕士及以上学历者优先。 2. 具有良好的代码能力，精通各类深度学习框架下，模型研发，熟练掌握Python、Java、C++等至少一种语言。 3. 具备快速阅读深度学习相关论文并理解算法的能力。 4. 针对上述人脸相关方向的深度学习建模具有3年及以上经验。
# =========
#  工作职责
# 1. 负责人脸身份认证领域算法模型研发，包括但不限于：人脸活体检测、人脸识别、人脸质量评估、人脸关键点检测、 图像加密、图像处理等方向的深度学习模型实际研发经验，具有炫彩活检研发经验者优先。 2. 负责深度学习模型压缩、模型剪枝等研发工作，具有便携终端轻量级模型研发经验者优先。
# 3. 负责跟踪上述领域的先进技术及研发工作。
# 4. 负责相关算法模型的产线开发、验证、优化及维护等产线工作。
# ———————————————————————————————————
# 任职要求
# 1. 计算机相关专业，大学本科毕业，硕士及以上学历者优先。
# 2. 具有良好的代码能力，精通各类深度学习框架下，模型研发，熟练掌握Python、Java、C++等至少一种语言。
# 3. 具备快速阅读深度学习相关论文并理解算法的能力。
# 4. 针对上述人脸相关方向的深度学习建模具有3年及以上经验。
# ——————————————————————————————————
# 本硕一个211，985，92年及以下，3年以上视觉算法，人脸活检、大模型都可以。
# 岗位职责：
# 1.负责计算机视觉算法和深度学习算法的前沿技术的研究工作；
# 2.近期负责小概率异常事件、复杂场景小目标检测、分布外检测等前沿技术研究；
# 任职要求：
# 1.图像处理与识别、计算机软件、数学、自动化等专业，硕士及以上毕业生，逻辑思维能力强，具备丰富的编程经验；
# 2.具有扎实的图像工程技术基础，深刻理解机器学习、深度学习等人工智能技术原理，在相关课题研究中取得一定成果，熟悉 caffe、pytorch、tensorflow 等深度学习框架；
# 3.具备良好的英文能力，能顺利阅读英文文献；
# 4.志存高远，具备强烈的责任感，进取心以及较强的学习专研能力、团队协助能力。
# ====================================
# {
#   "语言需求": ["英文"],
#   "框架需求": ["caffe", "pytorch", "tensorflow"],
#   "业务领域": [],
#   "算法与开发": ["计算机视觉算法", "深度学习算法", "小概率异常事件", "复杂场景小目标检测", "分布外检测", "机器学习", "人工智能技术原理"],
#   "其他要求": ["逻辑思维能力", "具备丰富的编程经验", "图像工程技术基础", "相关课题研究成果", "良好的英文能力", "志存高远", "责任感", "进取心", "学习专研能力", "团队协助能力"]
# }
# 工作职责
# 1. 负责人脸身份认证领域算法模型研发，包括但不限于：人脸活体检测、人脸识别、人脸质量评估、人脸关键点检测、 图像加密、图像处理等方向的深度学习模型实际研发经验，具有炫彩活检研发经验者优先。 2. 负责深度学习模型压缩、模型剪枝等研发工作，具有便携终端轻量级模型研发经验者优先。
# 3. 负责跟踪上述领域的先进技术及研发工作。
# 4. 负责相关算法模型的产线开发、验证、优化及维护等产线工作。
# ———————————————————————————————————
# 任职要求
# 1. 计算机相关专业，大学本科毕业，硕士及以上学历者优先。
# 2. 具有良好的代码能力，精通各类深度学习框架下，模型研发，熟练掌握Python、Java、C++等至少一种语言。
# 3. 具备快速阅读深度学习相关论文并理解算法的能力。
# 4. 针对上述人脸相关方向的深度学习建模具有3年及以上经验。
# ——————————————————————————————————
# 本硕一个211，985，92年及以下，3年以上视觉算法，人脸活检、大模型都可以。
# =========
#  工作职责
# 1. 负责人脸身份认证领域算法模型研发，包括但不限于：人脸活体检测、人脸识别、人脸质量评估、人脸关键点检测、 图像加密、图像处理等方向的深度学习模型实际研发经验，具有炫彩活检研发经验者优先。 2. 负责深度学习模型压缩、模型剪枝等研发工作，具有便携终端轻量级模型研发经验者优先。 3. 负责跟踪上述领域的先进技术及研发工作。 4. 负责相关算法模型的产线开发、验证、优化及维护等产线工作。
# 任职要求
# 1. 计算机相关专业，大学本科毕业，硕士及以上学历者优先。 2. 具有良好的代码能力，精通各类深度学习框架下，模型研发，熟练掌握Python、Java、C++等至少一种语言。 3. 具备快速阅读深度学习相关论文并理解算法的能力。 4. 针对上述人脸相关方向的深度学习建模具有3年及以上经验。
# 职位描述：
# 1. 负责基于计算机视觉/多模态技术的高精度、高质量地图POI数据的自动化生产和实时更新；
# 2. 负责研究和开发感知/识别等相关前沿技术，包括但不限于2D/3D目标检测、分割、匹配、深度估计、位姿估计等；
# 3. 参与其他创新应用预研。
# 职位要求：
# 1. 具备扎实的数学和计算机科学基础，具备良好的团队合作精神和沟通能力，熟练掌握计算机视觉领域的基础理论和方法；
# 2. 在一个或多个视觉应用领域有深入研究，如图像分类、2D/3D目标检测、目标分割、目标跟踪、BEV感知、自监督学习等；
# 3. 熟悉MLP、CNN、Transformer等网络架构；
# 4. 有较强的编程实现能力，熟练掌握Python，熟悉linux下开发环境，熟练掌握PyTorch等至少一种深度学习框架；
# 5. 具有快速学习能力，善于通过查阅文献资料解决问题。
# 具有以下者优先：
# 1. 在计算机视觉领域内的权威期刊（TPMAI/IJCV/TIP等）或顶级会议（CVPR/ICCV/ECCV等）发表过文章；
# 2. 在计算机视觉的通用或细分领域的权威竞赛中取得前三名；
# 3. 有机器学习/计算机视觉开源社区贡献；
# 4. 有模型压缩优化经验（剪枝、量化和蒸馏）；
# 5. 具备3D目标检测、BEV感知实践经验。
# =========
#  职位描述
# 1. 负责基于计算机视觉/多模态技术的高精度、高质量地图POI数据的自动化生产和实时更新；
# 2. 负责研究和开发感知/识别等相关前沿技术，包括但不限于2D/3D目标检测、分割、匹配、深度估计、位姿估计等；
# 3. 参与其他创新应用预研。
# 职位要求
# 岗位要求：
# 1. 具备扎实的数学和计算机科学基础，具备良好的团队合作精神和沟通能力，熟练掌握计算机视觉领域的基础理论和方法；
# 2. 在一个或多个视觉应用领域有深入研究，如图像分类、2D/3D目标检测、目标分割、目标跟踪、BEV感知、自监督学习等；
# 3. 熟悉MLP、CNN、Transformer等网络架构；
# 4. 有较强的编程实现能力，熟练掌握Python，熟悉linux下开发环境，熟练掌握PyTorch等至少一种深度学习框架；
# 6. 具有快速学习能力，善于通过查阅文献资料解决问题。
# 具有以下者优先：
# 1. 在计算机视觉领域内的权威期刊（TPMAI/IJCV/TIP等）或顶级会议（CVPR/ICCV/ECCV等）发表过文章；
# 2. 在计算机视觉的通用或细分领域的权威竞赛中取得前三名；
# 3. 有机器学习/计算机视觉开源社区贡献；
# 4. 有模型压缩优化经验（剪枝、量化和蒸馏）；
# 5. 具备3D目标检测、BEV感知实践经验。
# 职位详情：
# 1、负责手机相册场景下人脸语义分析方向的模型研发和迭代，包含人脸聚类，人脸颜值识别、人脸质量识别，人物关系识别，人脸跨年龄（儿童人脸识别）、跨肤色特征提取（多肤色人脸识别），服装特征提取，人脸生成等；
# 2、对上述算法进行轻量化研究以满足端侧部署要求；参与、推动技术落地到多个相册产品中。
# 3、探索大模型、生成模型、多模态、自监督等前沿技术；
# 职位要求
# 1、在计算机视觉某个领域有较深入的研究，包括但不限于：人脸识别、人脸聚类、AIGC、多模态预训练、人脸3DMM、神经辐射场、transformer模型等；
# 2、对深度学习算法有深刻理解，熟悉常用深度学习框架；
# 3、快速学习新技术的能力，能够在较短时间内理解前沿论文并评价；
# 4、有成果发表在CVPR、ICCV、ECCV、ICML、TPAMI等国际顶会顶刊者优先；在计算机视觉知名竞赛取得优异名次者优先；有高质量Github项目经验者优先；
# 5、积极主动有热情，能与团队合作相处，具备较强的沟通能力。
# =========
#  职位详情：
# 1、负责手机相册场景下人脸语义分析方向的模型研发和迭代，包含人脸聚类，人脸颜值识别、人脸质量识别，人物关系识别，人脸跨年龄（儿童人脸识别）、跨肤色特征提取（多肤色人脸识别），服装特征提取，人脸生成等；
# 2、对上述算法进行轻量化研究以满足端侧部署要求；参与、推动技术落地到手机端多个相册产品中；
# 3、探索大模型、生成模型、多模态、自监督等前沿技术；
# 职位要求：
# 1、在计算机视觉某个领域有较深入的研究，包括但不限于：人脸识别、人脸聚类、AIGC、多模态预训练、人脸3DMM、神经辐射场、transformer模型等；
# 2、对深度学习算法有深刻理解，熟悉常用深度学习框架；
# 3、快速学习新技术的能力，能够在较短时间内理解前沿论文并评价；
# 4、有成果发表在CVPR、ICCV、ECCV、ICML、TPAMI等国际顶会顶刊者优先；在计算机视觉知名竞赛取得优异名次者优先；有高质量Github项目经验者优先；
# 5、积极主动有热情，能与团队合作相处，具备较强的沟通能力。
# 工作职责
# 1.推荐召回与排序:超大规模的商品、视频、直播、主题推荐业务下的召回、排序、重混排模型，及跨域多模态推荐技术
# 2.认知推荐:基于GPT等新一代认知智能模型，建立新型认知推荐算法体系，结合新的交互式推荐的产品创新、提升用户交互体验
# 3.机制策略:通过深度强化学习技术优化推荐策略，设计智能流量机制，助力商业收入增长、商家及内容创作者成长
# 4.满智能:在端侧部季Smat A Aget,基于端云一体化的算法技术架构，实现端侧用户兴趣感为1、端侧智能决策,提升推荐效率和用户体验落地业务
# 任职要求
# 1、具备优秀的编码能力，扎实的数据结构和算法功底:
# 2、熟悉大规模机器学习/深度学习算法，
# 3、优秀的分析问题和解决问题的能力，对解决具有挑战性问题充满激情，不轻易放弃
# 4、对技术有热情，有自己的理解，能够用技术推动业务进步和变革
# 5、有良好的沟通表达能力，具有团队精神，有良好的团队协同能力: 6、在顶级计算机学术会议(SIGIR、SIGKDD、ICML、NIPS、WWW、AAAI、CIKMACL、RECSYS等)或期上发表过论文者
# ====================================
# {
#   "语言需求": [],
#   "框架需求": ["机器学习", "深度学习"],
#   "业务领域": ["推荐系统", "认知智能", "智能决策"],
#   "算法与开发": ["深度强化学习", "多模态推荐技术", "认知推荐算法"],
#   "其他要求": ["优秀的编码能力", "团队协同能力", "顶级计算机学术会议论文发表经验"]
# }
# 职能描述：
# 1. 持续跟进业内前沿技术，并能够结合实际业务场景提出创新的算法/模型；
# 2. 负责多模态/自监督学习领域的探索、实现及应用等相关工作，深度参与语音/视觉合成/迁移等模块的设计和编码；
# 3. 配合进行产品效率和稳定性优化，解决产品反馈的问题。
# 要求描述：
# 1. 计算机、数学、物理等相关专业硕士及以上学历；2-5年工作经验；
# 2. 对transfer learning、self-supervision有较深理解，有能力进行experiment及optimization；
# 3. 熟练掌握C++、Julia 或 Python，至少熟练使用一种深度学习框架（Tensorflow、PyTorch、PaddlePaddle），并有相关项目经验；
# 4. 有深度学习基础，熟悉常见机器学习、深度学习模型，并对创新算法保有探索和好奇心；
# 5. 良好的团队沟通能力，优秀的数理逻辑思维能力，上下求索，充满热情；
# 6. 有GAN、VAE、Flow-Base等生成式模型落地经验者优先；海归背景、985高校、或有过 Top coder、Kaggle 等比赛经历者优先。
# ====================================
# {
#   "语言需求": ["C++", "Julia", "Python"],
#   "框架需求": ["Tensorflow", "PyTorch", "PaddlePaddle"],
#   "业务领域": ["多模态", "自监督学习", "视觉合成"],
#   "算法与开发": ["transfer learning", "self-supervision", "生成式模型"],
#   "其他要求": ["计算机", "数学", "物理", "硕士", "团队沟通能力", "数理逻辑思维能力"]
# }
# 工作职责
# 1、负责面向公有云/大视频/视联网/物云融合/工业互联网等领域的图像、语音、文本等相关的算法研发。
# 2、负责计算机视觉、自然语言处理等机器学习前沿技术的研究，保持行业前沿水平，持续突破技术上限。
# 工作要求
# 1、大学本科及以上学历，并取得相应学位；
# 2、8年以上相关工作经验，5年以上研发管理经验优先，对AI应用落地有丰富经验；
# 2、具备丰富的机器学习相关领域经验，有大模型或项目落地经验着优先，有业界知名产品者优先；
# 3、有较强的前沿学术背景，在CVPR/ICCV/ECCV/ACL等顶级顶会或期刊有丰富的论文发表或指导经验优先；
# 4、在知名AI竞赛成绩优异者或者数据榜成绩出色者优先；
# 5、具备卓越的战略思维与执行能力，有较强的组织领导、沟通和；具有良好的敬业精神和职业道德操守，企业忠诚度高，并有良好的团队建设与管理经验。
# ====================================
# {
#   "语言需求": ["自然语言处理", "英语", "交流能力"],
#   "框架需求": [],
#   "业务领域": ["公有云", "大视频", "视联网"],
#   "算法与开发": ["计算机视觉", "机器学习", "大模型", "CVPR", "ICCV", "ECCV", "ACL", "AI竞赛", "数据榜"],
#   "其他要求": ["大学本科及以上学历", "8年以上工作经验", "5年以上研发管理经验", "前沿学术背景", "战略思维", "组织领导", "团队建设与管理经验"]
# }
# 职能描述：
# 1. 持续跟进业内前沿技术，并能够结合实际业务场景提出创新的算法/模型；
# 2. 负责多模态/自监督学习领域的探索、实现及应用等相关工作，深度参与语音/视觉合成/迁移等模块的设计和编码；
# 3. 配合进行产品效率和稳定性优化，解决产品反馈的问题。
# 要求描述：
# 1. 计算机、数学、物理等相关专业硕士及以上学历；2-5年工作经验；
# 2. 对transfer learning、self-supervision有较深理解，有能力进行experiment及optimization；
# 3. 熟练掌握C++、Julia 或 Python，至少熟练使用一种深度学习框架（Tensorflow、PyTorch、PaddlePaddle），并有相关项目经验；
# 4. 有深度学习基础，熟悉常见机器学习、深度学习模型，并对创新算法保有探索和好奇心；
# 5. 良好的团队沟通能力，优秀的数理逻辑思维能力，上下求索，充满热情；
# 6. 有GAN、VAE、Flow-Base等生成式模型落地经验者优先；海归背景、985高校、或有过 Top coder、Kaggle 等比赛经历者优先。
# =========
#  工作职能描述：
# 1. 持续跟进业内前沿技术，并能够结合实际业务场景提出创新的算法/模型；
# 2. 负责多模态/自监督学习领域的探索、实现及应用等相关工作，深度参与语音/视觉合成/迁移等模块的设计和编码；
# 3. 配合进行产品效率和稳定性优化，解决产品反馈的问题。
# 要求描述：
# ...
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_transports\default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\.pyenv\pyenv-win\versions\3.9.12\lib\contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_transports\default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10053] 你的主机中的软件中止了一个已建立的连接。
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_backends\sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_backends\sync.py:163, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     162         self._sock.settimeout(timeout)
# --> 163         sock = ssl_context.wrap_socket(
#     164             self._sock, server_hostname=server_hostname
#     165         )
#     166 except Exception as exc:  # pragma: nocover
#
# File ~\.pyenv\pyenv-win\versions\3.9.12\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~\.pyenv\pyenv-win\versions\3.9.12\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~\.pyenv\pyenv-win\versions\3.9.12\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File d:\virtualenv\town_env\lib\site-packages\httpx\_transports\default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_transports\default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_sync\http_proxy.py:317, in TunnelHTTPConnection.handle_request(self, request)
#     316 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 317     stream = stream.start_tls(**kwargs)
#     318     trace.return_value = stream
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_backends\sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File ~\.pyenv\pyenv-win\versions\3.9.12\lib\contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File d:\virtualenv\town_env\lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:878, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     877 try:
# --> 878     response = self._client.send(
#     879         request,
#     880         auth=self.custom_auth,
#     881         stream=stream or self._should_stream_response_body(request=request),
#     882     )
#     883 except httpx.TimeoutException as err:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_transports\default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\.pyenv\pyenv-win\versions\3.9.12\lib\contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File d:\virtualenv\town_env\lib\site-packages\httpx\_transports\default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[15], line 29
#       8     prompt = f"""
#       9 请提取招聘信息中岗位所涉及的与招聘相关的关键词，分别为“语言需求”、“框架需求”、“业务领域”、“算法与开发”和“其他要求”。
#      10
#    (...)
#      25 ```
#      26 """
#      27     if text not in s2e:
#      28         # get_embedding后，将文本与之前的文本进行相似度比较，如果相似度大于0.9，则将之前的文本的处理结果复制给当前文本
# ---> 29         s2e[text] = get_embedding(text, model="text-embedding-ada-002")
#      30     for k, v in s2e.items():
#      31         if k != text:
#
# File d:\AI\openaiRDA\test.py:56, in get_embedding(text, model, **kwargs)
#      51 def get_embedding(text: str, model="text-similarity-davinci-001", **kwargs) -> List[float]:
#      52
#      53     # replace newlines, which can negatively affect performance.
#      54     text = text.replace("\n", " ")
# ---> 56     response = client.embeddings.create(input = [text], model=model,**kwargs)
#      58     return response.data[0].embedding
#
# File d:\virtualenv\town_env\lib\site-packages\openai\resources\embeddings.py:106, in Embeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     100         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     101             base64.b64decode(data), dtype="float32"
#     102         ).tolist()
#     104     return obj
# --> 106 return self._post(
#     107     "/embeddings",
#     108     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     109     options=make_request_options(
#     110         extra_headers=extra_headers,
#     111         extra_query=extra_query,
#     112         extra_body=extra_body,
#     113         timeout=timeout,
#     114         post_parser=parser,
#     115     ),
#     116     cast_to=CreateEmbeddingResponse,
#     117 )
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:1089, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1075 def post(
#    1076     self,
#    1077     path: str,
#    (...)
#    1084     stream_cls: type[_StreamT] | None = None,
#    1085 ) -> ResponseT | _StreamT:
#    1086     opts = FinalRequestOptions.construct(
#    1087         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1088     )
# -> 1089     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:854, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     845 def request(
#     846     self,
#     847     cast_to: Type[ResponseT],
#    (...)
#     852     stream_cls: type[_StreamT] | None = None,
#     853 ) -> ResponseT | _StreamT:
# --> 854     return self._request(
#     855         cast_to=cast_to,
#     856         options=options,
#     857         stream=stream,
#     858         stream_cls=stream_cls,
#     859         remaining_retries=remaining_retries,
#     860     )
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:897, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     895 except Exception as err:
#     896     if retries > 0:
# --> 897         return self._retry_request(
#     898             options,
#     899             cast_to,
#     900             retries,
#     901             stream=stream,
#     902             stream_cls=stream_cls,
#     903             response_headers=None,
#     904         )
#     906     raise APIConnectionError(request=request) from err
#     908 log.debug(
#     909     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     910 )
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:959, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     955 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     956 # different thread if necessary.
#     957 time.sleep(timeout)
# --> 959 return self._request(
#     960     options=options,
#     961     cast_to=cast_to,
#     962     remaining_retries=remaining,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965 )
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:897, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     895 except Exception as err:
#     896     if retries > 0:
# --> 897         return self._retry_request(
#     898             options,
#     899             cast_to,
#     900             retries,
#     901             stream=stream,
#     902             stream_cls=stream_cls,
#     903             response_headers=None,
#     904         )
#     906     raise APIConnectionError(request=request) from err
#     908 log.debug(
#     909     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     910 )
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:959, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     955 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     956 # different thread if necessary.
#     957 time.sleep(timeout)
# --> 959 return self._request(
#     960     options=options,
#     961     cast_to=cast_to,
#     962     remaining_retries=remaining,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965 )
#
# File d:\virtualenv\town_env\lib\site-packages\openai\_base_client.py:906, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     896     if retries > 0:
#     897         return self._retry_request(
#     898             options,
#     899             cast_to,
#    (...)
#     903             response_headers=None,
#     904         )
# --> 906     raise APIConnectionError(request=request) from err
#     908 log.debug(
#     909     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     910 )
#     912 try:
#
# APIConnectionError: Connection error.

# %%
# import json
# new_cache = {k: json.loads(v) for k, v in new_cache.items()}

# %%
with open("data/all_keyword_dic.cache", "wb") as f:
    pickle.dump(new_cache, f)

# %%
with open("data/s2e.cache", "wb") as f:
    pickle.dump(s2e, f)

# %%
len(new_cache)
# Out:
# 347

# %%
# 提取所有其他要求中的关键词
other_keywords = []
for k, v in new_cache.items():
    other_keywords.extend(v["其他要求"])
other_keywords = list(set(other_keywords))
len(other_keywords)
# Out:
# 812

# %%
# 对其他要求中的关键词根据sequencematcher进行相似度比较，如果相似度大于0.9，则制作成字典
# 使用sequencematcher做初步筛选
from difflib import SequenceMatcher
from collections import defaultdict
k2kl = defaultdict(list)

for i in range(len(other_keywords)):
    for j in range(i + 1, len(other_keywords)):
        if "经验" in other_keywords[i] and "经验" in other_keywords[j]:
            continue
        if SequenceMatcher(None, other_keywords[i], other_keywords[j]).ratio() > 0.8:
            print(other_keywords[i], ":", other_keywords[j])
            k2kl[other_keywords[i]].append(other_keywords[j])

# %%
# 根据k2kl，将other_keywords中的关键词替换为相似度最高的关键词
for k, v in k2kl.items():
    for i in range(len(other_keywords)):
        if other_keywords[i] in v:
            other_keywords[i] = k

# %%
other_keywords = list(set(other_keywords))
len(other_keywords)
# Out:
# 731

# %%
# common_keys = set(new_cache.keys()).intersection(s2e.keys())
# result_dict = {key: s2e[key] for key in common_keys}
# len(result_dict)
# s2e = result_dict
